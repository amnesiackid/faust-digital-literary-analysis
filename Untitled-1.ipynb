# %%
from lxml import etree
import os

# Correct file path – make sure this file really lives in your notebook's CWD
file_path = "data\Faust._Der_Tragoedie_erster_Teil.11g9p.0.xml"

# Parse XML
tree = etree.parse(file_path)
root = tree.getroot()

# Check what tags exist
tags = set(elem.tag for elem in root.iter())
for tag in tags:
    print(tag)
# Out:
# {http://www.tei-c.org/ns/1.0}notesStmt
# {http://www.tei-c.org/ns/1.0}pubPlace
# {http://www.tei-c.org/ns/1.0}note
# {http://www.tei-c.org/ns/1.0}author
# {http://www.tei-c.org/ns/1.0}sourceDesc
# {http://www.tei-c.org/ns/1.0}langUsage
# {http://www.tei-c.org/ns/1.0}teiCorpus
# {http://www.tei-c.org/ns/1.0}teiHeader
# {http://www.tei-c.org/ns/1.0}ab
# {http://www.tei-c.org/ns/1.0}titleStmt
# {http://www.tei-c.org/ns/1.0}extent
# {http://www.tei-c.org/ns/1.0}speaker
# {http://www.tei-c.org/ns/1.0}TEI
# {http://www.tei-c.org/ns/1.0}creation
# {http://www.tei-c.org/ns/1.0}lg
# {http://www.tei-c.org/ns/1.0}head
# {http://www.tei-c.org/ns/1.0}text
# {http://www.tei-c.org/ns/1.0}textClass
# {http://www.tei-c.org/ns/1.0}l
# {http://www.tei-c.org/ns/1.0}date
# {http://www.tei-c.org/ns/1.0}resp
# {http://www.tei-c.org/ns/1.0}language
# {http://www.tei-c.org/ns/1.0}fileDesc
# {http://www.tei-c.org/ns/1.0}lb
# {http://www.tei-c.org/ns/1.0}keywords
# {http://www.tei-c.org/ns/1.0}respStmt
# {http://www.tei-c.org/ns/1.0}div
# {http://www.tei-c.org/ns/1.0}pb
# {http://www.tei-c.org/ns/1.0}idno
# {http://www.tei-c.org/ns/1.0}name
# {http://www.tei-c.org/ns/1.0}stage
# {http://www.tei-c.org/ns/1.0}hi
# {http://www.tei-c.org/ns/1.0}sp
# {http://www.tei-c.org/ns/1.0}profileDesc
# {http://www.tei-c.org/ns/1.0}publicationStmt
# {http://www.tei-c.org/ns/1.0}biblFull
# {http://www.tei-c.org/ns/1.0}term
# {http://www.tei-c.org/ns/1.0}body
# {http://www.tei-c.org/ns/1.0}ref
# {http://www.tei-c.org/ns/1.0}front
# {http://www.tei-c.org/ns/1.0}availability
# {http://www.tei-c.org/ns/1.0}p
# {http://www.tei-c.org/ns/1.0}desc
# {http://www.tei-c.org/ns/1.0}title

# %%
# Register TEI namespace
ns = {'tei': "http://www.tei-c.org/ns/1.0"}# Check all div types
divs = tree.xpath("//tei:div", namespaces=ns)
types = set(div.get("type") for div in divs if div.get("type") is not None)

print("All div types found:", types)
# Out:
# All div types found: {'h4', 'front', 'text'}

# %% [markdown]
# # Extract Scene

# %%
# build a list of only those <div>s you want to call “Scene”
scene_divs = [d for d in divs if d.find("tei:head", namespaces=ns) is not None]
scenes = []
for i, div in enumerate(scene_divs, start=1):
    head = div.find("tei:head", namespaces=ns)
    scenes.append(head)
for scene in scenes:
    print("Scene:", scene.text)
# Out:
# Scene: Der Tragödie erster Teil.
# Scene: Nacht.
# Scene: Vor dem Tor.
# Scene: Studierzimmer.
# Scene: Studierzimmer.
# Scene: Auerbachs Keller in Leipzig.
# Scene: Hexenküche.
# Scene: Straße.
# Scene: Abend.
# Scene: Spaziergang.
# Scene: Der Nachbarin Haus.
# Scene: Straße.
# Scene: Garten.
# Scene: Ein Gartenhäuschen.
# Scene: Wald und Höhle.
# Scene: Gretchens Stube.
# Scene: Marthens Garten.
# Scene: Am Brunnen.
# Scene: Zwinger.
# Scene: Nacht.
# Scene: Dom.
# Scene: Walpurgisnacht.
# Scene: Walpurgisnachtstraum
# Scene: Trüber Tag. Feld.
# Scene: Nacht. Offen Feld.
# Scene: Kerker.

# %%
import spacy
# 2. 预加载德语分词模型和停止词（只做一次）
nlp = spacy.load("de_core_news_sm")
stopwords = set(nlp.Defaults.stop_words)

# %%
from collections import Counter

# collect speaker stats per scene (only divs that have a tei:head)
scene_divs = [d for d in divs 
              if d.find('tei:head', namespaces=ns) is not None]
scene_stats = []

for idx, div in enumerate(scene_divs, start=1):
    head = div.find('tei:head', namespaces=ns)
    title = head.text.strip() if head is not None else f"Scene {idx}"
    scene_info = {
        "scene_num": idx,
        "scene_title": title,
        "speakers": {}
    }

    for sp in div.findall('.//tei:sp', namespaces=ns):
        sp_el = sp.find('tei:speaker', namespaces=ns)
        if sp_el is None:
            continue
        speaker = sp_el.text.strip()
        stats = scene_info["speakers"].setdefault(
            speaker,
            {"lines": 0, "word_freq": Counter()}
        )

        for l in sp.findall('.//tei:l', namespaces=ns):
            text = (l.text or '').strip()
            if not text:
                continue
            stats["lines"] += 1
            doc = nlp(text)
            for tok in doc:
                if tok.is_alpha:
                    lemma = tok.lemma_.lower()
                    if lemma not in stopwords:
                        stats["word_freq"][lemma] += 1

    # convert Counter to regular dict for JSON serialization
    for s, info in scene_info["speakers"].items():
        # sort word_freq by descending count:
        info["word_freq"] = dict(
            sorted(
                info["word_freq"].items(),
                key=lambda item: item[1],
                reverse=True
            )
        )

    scene_stats.append(scene_info)

scene_stats
# Out:
# [{'scene_num': 1, 'scene_title': 'Der Tragödie erster Teil.', 'speakers': {}},
#  {'scene_num': 2,
#   'scene_title': 'Nacht.',
#   'speakers': {'FAUST.': {'lines': 207,
#     'word_freq': {'herz': 11,
#      'geist': 9,
#      'welt': 7,
#      'erde': 6,
#      'leben': 5,
#      'sinn': 5,
#      'heiß': 4,
#      'natur': 4,
#      'fühlen': 4,
#      'herab': 3,
#      'wissen': 3,
#      'mensch': 3,
#      'kraft': 3,
#      'mund': 3,
#      'erkennen': 3,
#      'buch': 3,
#      'freund': 3,
#      'licht': 3,
#      'weh': 3,
#      'heißen': 3,
#      'gott': 3,
#      'eign': 3,
#      'zeichen': 3,
#      'seele': 3,
#      'brust': 3,
#      'all': 3,
#      'neu': 3,
#      'gefühl': 3,
#      'kind': 3,
#      'ernst': 3,
#      'arm': 2,
#      'tor': 2,
#      'magister': 2,
#      'doktor': 2,
#      'schüler': 2,
#      'verbrennen': 2,
#      'weder': 2,
#      'bild': 2,
#      'hab': 2,
#      'sagen': 2,
#      'wort': 2,
#      'papier': 2,
#      'lieb': 2,
#      'schweben': 2,
#      'wiese': 2,
#      'weben': 2,
#      'dumpf': 2,
#      'gewölb': 2,
#      'rings': 2,
#      'schaffen': 2,
#      'geheimnisvoll': 2,
#      'stern': 2,
#      'sprechen': 2,
#      'anderer': 2,
#      'ha': 2,
#      'blick': 2,
#      'stillen': 2,
#      'trieb': 2,
#      'wirken': 2,
#      'himmel': 2,
#      'dringen': 2,
#      'welch': 2,
#      'schauspiel': 2,
#      'nah': 2,
#      'fühl': 2,
#      'glück': 2,
#      'tragen': 2,
#      'mußt': 2,
#      'eur': 2,
#      'quillen': 2,
#      'o': 2,
#      'tief': 2,
#      'nacht': 2,
#      'klingen': 2,
#      'hold': 2,
#      'jugend': 2,
#      'philosophie': 1,
#      'juristerei': 1,
#      'medizin': 1,
#      'theologie': 1,
#      'studieren': 1,
#      'bemühn': 1,
#      'steh': 1,
#      'klug': 1,
#      'zuvor': 1,
#      'ziehen': 1,
#      'zeh': 1,
#      'herauf': 1,
#      'quer': 1,
#      'krumm': 1,
#      'nase': 1,
#      'herum': 1,
#      'sehen': 1,
#      'schier': 1,
#      'gescheit': 1,
#      'laffe': 1,
#      'schreiber': 1,
#      'pfaffe': 1,
#      'plagen': 1,
#      'skrupel': 1,
#      'zweifel': 1,
#      'fürchte': 1,
#      'hölle': 1,
#      'teufel': 1,
#      'freud': 1,
#      'entreißen': 1,
#      'lehren': 1,
#      'bessern': 1,
#      'bekehren': 1,
#      'geld': 1,
#      'ehr': 1,
#      'herrlichkeit': 1,
#      'möchten': 1,
#      'hund': 1,
#      'drum': 1,
#      'magie': 1,
#      'ergeben': 1,
#      'manch': 1,
#      'geheimnis': 1,
#      'kund': 1,
#      'sauerm': 1,
#      'schweiß': 1,
#      'brauchen': 1,
#      'innerst': 1,
#      'zusammenhalten': 1,
#      'schau': 1,
#      'wirkenskraft': 1,
#      'samen': 1,
#      'tu': 1,
#      'kramen': 1,
#      'letztenmal': 1,
#      'pein': 1,
#      'mitternacht': 1,
#      'pult': 1,
#      'herangewacht': 1,
#      'erschiensen': 1,
#      'bergeshöhn': 1,
#      'gehn': 1,
#      'bergeshöhle': 1,
#      'geister': 1,
#      'dämmer': 1,
#      'wissensqualm': 1,
#      'entladen': 1,
#      'tau': 1,
#      'gesund': 1,
#      'baden': 1,
#      'steck': 1,
#      'kerker': 1,
#      'verflucht': 1,
#      'mauerloch': 1,
#      'himmelslicht': 1,
#      'trüb': 1,
#      'gemalt': 1,
#      'scheibe': 1,
#      'brechen': 1,
#      'beschränkt': 1,
#      'bücherhauf': 1,
#      'würme': 1,
#      'nagen': 1,
#      'staub': 1,
#      'bedeckt': 1,
#      'hinauf': 1,
#      'angeraucht': 1,
#      'umstecken': 1,
#      'gläser': 1,
#      'büchsen': 1,
#      'umstellen': 1,
#      'instrument': 1,
#      'vollgepfropfen': 1,
#      'drein': 1,
#      'stopfen': 1,
#      'fragst': 1,
#      'bingen': 1,
#      'busen': 1,
#      'klemmen': 1,
#      'unerklärt': 1,
#      'schmerz': 1,
#      'lebensregung': 1,
#      'hemmen': 1,
#      'lebendig': 1,
#      'hinein': 1,
#      'umgibt': 1,
#      'rauch': 1,
#      'moder': 1,
#      'tiergeripp': 1,
#      'totenbein': 1,
#      'flieh': 1,
#      'hinaus': 1,
#      'land': 1,
#      'nostradamus': 1,
#      'hand': 1,
#      'geleit': 1,
#      'erkennest': 1,
#      'lauf': 1,
#      'seelenkraft': 1,
#      'umsonst': 1,
#      'trockn': 1,
#      'erklären': 1,
#      'antworten': 1,
#      'hören': 1,
#      'wonne': 1,
#      'fließen': 1,
#      'jung': 1,
#      'lebensglück': 1,
#      'neuglühend': 1,
#      'nerv': 1,
#      'ader': 1,
#      'rinnen': 1,
#      'schreiben': 1,
#      'innre': 1,
#      'toben': 1,
#      'freude': 1,
#      'füllen': 1,
#      'enthüllen': 1,
#      'schaun': 1,
#      'rein': 1,
#      'züg': 1,
#      'wirkend': 1,
#      'liegen': 1,
#      'erkenn': 1,
#      'weise': 1,
#      'geisterwelt': 1,
#      'verschlossen': 1,
#      'tot': 1,
#      'bade': 1,
#      'unverdrossen': 1,
#      'eins': 1,
#      'himmelskräfte': 1,
#      'nieder': 1,
#      'steigen': 1,
#      'goldn': 1,
#      'eimer': 1,
#      'reichen': 1,
#      'segenduftend': 1,
#      'schwing': 1,
#      'harmonisch': 1,
#      'durchklingen': 1,
#      'fass': 1,
#      'unendlich': 1,
#      'quelle': 1,
#      'hängen': 1,
#      'welk': 1,
#      'drängen': 1,
#      'glüh': 1,
#      'wein': 1,
#      'mut': 1,
#      'wagen': 1,
#      'stürm': 1,
#      'herumschlagen': 1,
#      'schiffbruch': 1,
#      'knirsch': 1,
#      'zagen': 1,
#      'wölkt': 1,
#      'mond': 1,
#      'verbergen': 1,
#      'lampe': 1,
#      'schwinden': 1,
#      'dampfen': 1,
#      'zucken': 1,
#      'rot': 1,
#      'strahl': 1,
#      'haupt': 1,
#      'wehen': 1,
#      'schauer': 1,
#      'fassen': 1,
#      'schwebst': 1,
#      'erfleht': 1,
#      'enthülle': 1,
#      'reißen': 1,
#      'erwühlen': 1,
#      'hingegeben': 1,
#      'kosten': 1,
#      'ertrag': 1,
#      'flammenbildung': 1,
#      'weichen': 1,
#      'faust': 1,
#      'deinesgleichen': 1,
#      'umschweifst': 1,
#      'geschäftig': 1,
#      'pfarrer': 1,
#      'komödiant': 1,
#      'erjagen': 1,
#      'urkräftig': 1,
#      'behag': 1,
#      'hörer': 1,
#      'zwingen': 1,
#      'sitzt': 1,
#      'leimt': 1,
#      'brauen': 1,
#      'ragout': 1,
#      'andr': 1,
#      'schmaus': 1,
#      'blastn': 1,
#      'kümmerlich': 1,
#      'flamme': 1,
#      'aschenhäufchen': 1,
#      'raus': 1,
#      'bewundrung': 1,
#      'affe': 1,
#      'darnach': 1,
#      'gaumen': 1,
#      'stehen': 1,
#      'such': 1,
#      'redlich': 1,
#      'gewinn': 1,
#      'schellenlaut': 1,
#      'verstand': 1,
#      'kunst': 1,
#      'selber': 1,
#      'nötig': 1,
#      'nachjagen': 1,
#      'rede': 1,
#      'blinkend': 1,
#      'menschheit': 1,
#      'schnitzel': 1,
#      'kräuseln': 1,
#      'unerquicklich': 1,
#      'nebelwind': 1,
#      'herbstlich': 1,
#      'dürr': 1,
#      'blatt': 1,
#      'säuseln': 1,
#      'pergament': 1,
#      'bronn': 1,
#      'woraus': 1,
#      'trunk': 1,
#      'durst': 1,
#      'ewig': 1,
#      'vergangenheit': 1,
#      'siegel': 1,
#      'grund': 1,
#      'herr': 1,
#      'bespiegeln': 1,
#      'wahrlich': 1,
#      'jammer': 1,
#      'laufen': 1,
#      'kehrichtfaß': 1,
#      'rumpelkammer': 1,
#      'höchstens': 1,
#      'staatsaktion': 1,
#      'trefflich': 1,
#      'pragmatisch': 1,
#      'maxime': 1,
#      'pupp': 1,
#      'ziemen': 1,
#      'name': 1,
#      'nennen': 1,
#      'törichen': 1,
#      'gnug': 1,
#      'voll': 1,
#      'wahrten': 1,
#      'pöbel': 1,
#      'schauen': 1,
#      'offenbaren': 1,
#      'kreuzigen': 1,
#      'beten': 1,
#      'diesmal': 1,
#      'unterbrechen': 1,
#      'summe': 1,
#      'hell': 1,
#      'ton': 1,
#      'zieht': 1,
#      'gewalt': 1,
#      'glas': 1,
#      'verkündiget': 1,
#      'glocke': 1,
#      'osterfest': 1,
#      'feierstunde': 1,
#      'chöre': 1,
#      'singen': 1,
#      'tröstlich': 1,
#      'gesang': 1,
#      'einst': 1,
#      'grabe': 1,
#      'engelslippe': 1,
#      'gewißheit': 1,
#      'bund': 1,
#      'suchen': 1,
#      'mächtig': 1,
#      'gelind': 1,
#      'himmelstöne': 1,
#      'staube': 1,
#      'klingt': 1,
#      'umher': 1,
#      'weich': 1,
#      'botschaft': 1,
#      'hör': 1,
#      'fehlen': 1,
#      'glaube': 1,
#      'wunder': 1,
#      'glauben': 1,
#      'liebst': 1,
#      'sphäre': 1,
#      'wag': 1,
#      'streben': 1,
#      'woher': 1,
#      'nachricht': 1,
#      'tönen': 1,
#      'klang': 1,
#      'wöhnen': 1,
#      'ruft': 1,
#      'stürzen': 1,
#      'himmelslieb': 1,
#      'kuß': 1,
#      'sabbatstille': 1,
#      'ahnungsvoll': 1,
#      'glockenton': 1,
#      'fülle': 1,
#      'gebet': 1,
#      'brünstig': 1,
#      'genuß': 1,
#      'unbegreiflich': 1,
#      'sehnen': 1,
#      'wald': 1,
#      'hinzugehn': 1,
#      'tausend': 1,
#      'träne': 1,
#      'fühlt': 1,
#      'entstehn': 1,
#      'lied': 1,
#      'verkünden': 1,
#      'muntre': 1,
#      'spiel': 1,
#      'frühlingsfeier': 1,
#      'frei': 1,
#      'erinnrung': 1,
#      'halten': 1,
#      'kindlich': 1,
#      'letzter': 1,
#      'schritt': 1,
#      'töneen': 1,
#      'fort': 1,
#      'süß': 1,
#      'himmelslieder': 1,
#      'tran': 1}},
#    'GEIST.': {'lines': 27,
#     'word_freq': {'mächtig': 2,
#      'stimme': 2,
#      'webe': 2,
#      'rufen': 1,
#      'anziehen': 1,
#      'sphäre': 1,
#      'sogen': 1,
#      'flehst': 1,
#      'eratmend': 1,
#      'schauen': 1,
#      'hören': 1,
#      'antlitz': 1,
#      'sehn': 1,
#      'neigen': 1,
#      'seelenflehn': 1,
#      'welch': 1,
#      'erbärmlich': 1,
#      'grauen': 1,
#      'faßt': 1,
#      'übermenschen': 1,
#      'seele': 1,
#      'ruf': 1,
#      'brust': 1,
#      'welt': 1,
#      'erschuf': 1,
#      'tragen': 1,
#      'hegen': 1,
#      'freudebebe': 1,
#      'faust': 1,
#      'erklingen': 1,
#      'kraft': 1,
#      'drangn': 1,
#      'hauch': 1,
#      'umwitteren': 1,
#      'lebenstief': 1,
#      'zitteren': 1,
#      'furchtsam': 1,
#      'weggekrümmt': 1,
#      'wurm': 1,
#      'lebensfluten': 1,
#      'tatensturm': 1,
#      'wall': 1,
#      'geburt': 1,
#      'grab': 1,
#      'ewig': 1,
#      'meer': 1,
#      'wechselnd': 1,
#      'glühend': 1,
#      'leben': 1,
#      'schaff': 1,
#      'sausend': 1,
#      'webstuhl': 1,
#      'wirken': 1,
#      'gottheit': 1,
#      'lebendig': 1,
#      'kleid': 1,
#      'gleichst': 1,
#      'geist': 1,
#      'begreifst': 1}},
#    'FAUST': {'lines': 140,
#     'word_freq': {'neu': 5,
#      'kraft': 4,
#      'leben': 4,
#      'fühlen': 3,
#      'geist': 3,
#      'alt': 3,
#      'gesicht': 2,
#      'ebenbild': 2,
#      'gottheit': 2,
#      'finden': 2,
#      'wahrheit': 2,
#      'natur': 2,
#      'augenblick': 2,
#      'klein': 2,
#      'unsr': 2,
#      'fremd': 2,
#      'phantasie': 2,
#      'tief': 2,
#      'schmerz': 2,
#      'lust': 2,
#      'stets': 2,
#      'staub': 2,
#      'schwer': 2,
#      'stehen': 2,
#      'brauchen': 2,
#      'nützen': 2,
#      'kunst': 2,
#      'hold': 2,
#      'rein': 2,
#      'höhle': 2,
#      'vieler': 2,
#      'zugebrachen': 2,
#      'schrecklich': 1,
#      'klopfen': 1,
#      'o': 1,
#      'tod': 1,
#      'famulus': 1,
#      'schönst': 1,
#      'glück': 1,
#      'zunichte': 1,
#      'fülle': 1,
#      'trockne': 1,
#      'schleicher': 1,
#      'stören': 1,
#      'kopf': 1,
#      'hoffnung': 1,
#      'schwinden': 1,
#      'immerfort': 1,
#      'schal': 1,
#      'zeuge': 1,
#      'kleben': 1,
#      'hand': 1,
#      'schatz': 1,
#      'graben': 1,
#      'froh': 1,
#      'regenwürmer': 1,
#      'geisterfülle': 1,
#      'umgeben': 1,
#      'ertönen': 1,
#      'diesmal': 1,
#      'ärmlich': 1,
#      'erdensöhn': 1,
#      'rissesen': 1,
#      'verzweiflung': 1,
#      'sinn': 1,
#      'zerstören': 1,
#      'erscheinung': 1,
#      'riesengroß': 1,
#      'zwerg': 1,
#      'empfinden': 1,
#      'nah': 1,
#      'dünken': 1,
#      'spiegel': 1,
#      'genoß': 1,
#      'himmelsglanz': 1,
#      'klarheit': 1,
#      'abgestreifen': 1,
#      'erdensohn': 1,
#      'cherub': 1,
#      'frei': 1,
#      'ader': 1,
#      'fließen': 1,
#      'schaffend': 1,
#      'götterleben': 1,
#      'genießen': 1,
#      'ahnungsvoll': 1,
#      'vermaß': 1,
#      'büßen': 1,
#      'donnerwort': 1,
#      'hinwegraffen': 1,
#      'vermessen': 1,
#      'hab': 1,
#      'anzuziehn': 1,
#      'besessen': 1,
#      'hatt': 1,
#      'halten': 1,
#      'stießest': 1,
#      'grausam': 1,
#      'zurücken': 1,
#      'ungewisse': 1,
#      'menschenlos': 1,
#      'lehret': 1,
#      'meiden': 1,
#      'gehorch': 1,
#      'drang': 1,
#      'leiden': 1,
#      'hemmen': 1,
#      'unsrer': 1,
#      'gang': 1,
#      'herrlichst': 1,
#      'empfangen': 1,
#      'drängt': 1,
#      'stoff': 1,
#      'welt': 1,
#      'gelangen': 1,
#      'heißen': 1,
#      'beßre': 1,
#      'trug': 1,
#      'wahn': 1,
#      'geben': 1,
#      'herrlich': 1,
#      'gefühl': 1,
#      'erstarr': 1,
#      'irdisch': 1,
#      'gewühl': 1,
#      'kühn': 1,
#      'flug': 1,
#      'hoffnungsvoll': 1,
#      'ewigen': 1,
#      'erweitern': 1,
#      'raum': 1,
#      'sorge': 1,
#      'nisten': 1,
#      'herz': 1,
#      'wirket': 1,
#      'geheim': 1,
#      'unruhig': 1,
#      'wiegen': 1,
#      'störet': 1,
#      'ruh': 1,
#      'decken': 1,
#      'maske': 1,
#      'haus': 1,
#      'hof': 1,
#      'weib': 1,
#      'kind': 1,
#      'erscheinen': 1,
#      'feuer': 1,
#      'wasser': 1,
#      'dolch': 1,
#      'gift': 1,
#      'bebst': 1,
#      'treffen': 1,
#      'verliersen': 1,
#      'mußt': 1,
#      'beweinen': 1,
#      'götter': 1,
#      'wurme': 1,
#      'durchwühlen': 1,
#      'staube': 1,
#      'nährend': 1,
#      'wandrer': 1,
#      'tritt': 1,
#      'vernichten': 1,
#      'begraben': 1,
#      'wand': 1,
#      'hundert': 1,
#      'fach': 1,
#      'verenget': 1,
#      'trödel': 1,
#      'tausendfach': 1,
#      'tand': 1,
#      'mottenwelt': 1,
#      'drängeen': 1,
#      'fehlen': 1,
#      'tausend': 1,
#      'buch': 1,
#      'lesen': 1,
#      'überall': 1,
#      'mensch': 1,
#      'quälen': 1,
#      'hie': 1,
#      'glücklicher': 1,
#      'grinsest': 1,
#      'hohl': 1,
#      'schädel': 1,
#      'hirn': 1,
#      'einst': 1,
#      'verwirret': 1,
#      'suchen': 1,
#      'dämmrung': 1,
#      'jämmerlich': 1,
#      'geirret': 1,
#      'instrument': 1,
#      'freilich': 1,
#      'spotten': 1,
#      'rad': 1,
#      'kämmen': 1,
#      'walz': 1,
#      'bügel': 1,
#      'tor': 1,
#      'schlüssel': 1,
#      'eu': 1,
#      'bart': 1,
#      'kraus': 1,
#      'heben': 1,
#      'riegel': 1,
#      'geheimnisvoll': 1,
#      'licht': 1,
#      'lassen': 1,
#      'schleier': 1,
#      'berauben': 1,
#      'offenbaren': 1,
#      'zwingst': 1,
#      'hebel': 1,
#      'schraube': 1,
#      'gerät': 1,
#      'vater': 1,
#      'rolle': 1,
#      'anrauchen': 1,
#      'pult': 1,
#      'trüb': 1,
#      'lampe': 1,
#      'schmauchen': 1,
#      'hätn': 1,
#      'verprassen': 1,
#      'ererben': 1,
#      'vätern': 1,
#      'erwirb': 1,
#      'besitzen': 1,
#      'last': 1,
#      'erschaffen': 1,
#      'heften': 1,
#      'blick': 1,
#      'stelle': 1,
#      'fläschchen': 1,
#      'auge': 1,
#      'magnet': 1,
#      'lieblich': 1,
#      'hellen': 1,
#      'wald': 1,
#      'mondenglanz': 1,
#      'umwehen': 1,
#      'grüßen': 1,
#      'einzig': 1,
#      'phiole': 1,
#      'andacht': 1,
#      'herunterholen': 1,
#      'verehr': 1,
#      'menschenwitz': 1,
#      'inbegriff': 1,
#      'schlummersäfte': 1,
#      'auszug': 1,
#      'tödlich': 1,
#      'fein': 1,
#      'erweise': 1,
#      'meister': 1,
#      'gunst': 1,
#      'sehen': 1,
#      'lindern': 1,
#      'fassen': 1,
#      'streben': 1,
#      'mindern': 1,
#      'flutstrom': 1,
#      'ebbet': 1,
#      'meer': 1,
#      'hinausgewiesen': 1,
#      'spiegelflut': 1,
#      'erglänzen': 1,
#      'fuß': 1,
#      'ufer': 1,
#      'locken': 1,
#      'feuerwage': 1,
#      'schweben': 1,
#      'schwing': 1,
#      'heran': 1,
#      'bereit': 1,
#      'bahn': 1,
#      'äther': 1,
#      'durchdringen': 1,
#      'sphäre': 1,
#      'tätigkeit': 1,
#      'götterwonn': 1,
#      'wurm': 1,
#      'verdienest': 1,
#      'kehren': 1,
#      'erdensonne': 1,
#      'entschlossen': 1,
#      'rücken': 1,
#      'vermeß': 1,
#      'pfort': 1,
#      'aufreißen': 1,
#      'vorüberschleichen': 1,
#      'beweisen': 1,
#      'manneswürde': 1,
#      'götterhöhe': 1,
#      'weichen': 1,
#      'dunkeln': 1,
#      'beben': 1,
#      'eign': 1,
#      'qual': 1,
#      'verdammen': 1,
#      'durchgang': 1,
#      'hinzusterben': 1,
#      'eng': 1,
#      'mund': 1,
#      'hölle': 1,
#      'flammen': 1,
#      'wär': 1,
#      'gefahr': 1,
#      'dahinzufließen': 1,
#      'herab': 1,
#      'kristalln': 1,
#      'schale': 1,
#      'hervor': 1,
#      'futterale': 1,
#      'denken': 1,
#      'glänztest': 1,
#      'väter': 1,
#      'freudenfest': 1,
#      'erheitertest': 1,
#      'ernst': 1,
#      'gast': 1,
#      'anderer': 1,
#      'bild': 1,
#      'künstlich': 1,
#      'reich': 1,
#      'pracht': 1,
#      'trinker': 1,
#      'pflicht': 1,
#      'reimweis': 1,
#      'erklären': 1,
#      'zug': 1,
#      'höhlung': 1,
#      'auszuleeren': 1,
#      'erinnert': 1,
#      'jugendnacht': 1,
#      'nachbar': 1,
#      'reichen': 1,
#      'witz': 1,
#      'zeigen': 1,
#      'saft': 1,
#      'eilig': 1,
#      'trunken': 1,
#      'braun': 1,
#      'flut': 1,
#      'erfüllen': 1,
#      'bereiten': 1,
#      'wählen': 1,
#      'letzter': 1,
#      'trunk': 1,
#      'seele': 1,
#      'festlich': 1,
#      'gruß': 1}},
#    'WAGNER.': {'lines': 32,
#     'word_freq': {'verzeiht': 2,
#      'kunst': 2,
#      'möchen': 2,
#      'hab': 2,
#      'lehren': 2,
#      'welt': 2,
#      'geist': 2,
#      'wissen': 2,
#      'hör': 1,
#      'deklamieren': 1,
#      'last': 1,
#      'gewiß': 1,
#      'griechisch': 1,
#      'trauerspiel': 1,
#      'profitieren': 1,
#      'heutzutage': 1,
#      'wirken': 1,
#      'öfter': 1,
#      'rühme': 1,
#      'hören': 1,
#      'komödiant': 1,
#      'pfarrer': 1,
#      'museum': 1,
#      'bannen': 1,
#      'sehen': 1,
#      'feiertag': 1,
#      'ferngla': 1,
#      'überredung': 1,
#      'leiten': 1,
#      'vortrag': 1,
#      'redner': 1,
#      'glück': 1,
#      'fühl': 1,
#      'gott': 1,
#      'leben': 1,
#      'kritisch': 1,
#      'bestreben': 1,
#      'kopf': 1,
#      'busen': 1,
#      'bingen': 1,
#      'schwer': 1,
#      'erwerben': 1,
#      'quelle': 1,
#      'steigen': 1,
#      'eh': 1,
#      'halb': 1,
#      'weg': 1,
#      'erreichen': 1,
#      'arm': 1,
#      'teufel': 1,
#      'sterben': 1,
#      'ergetze': 1,
#      'versetzen': 1,
#      'schauen': 1,
#      'weis': 1,
#      'mann': 1,
#      'denken': 1,
#      'zuletzt': 1,
#      'herrlich': 1,
#      'bringen': 1,
#      'mensch': 1,
#      'herz': 1,
#      'möcht': 1,
#      'jeglicher': 1,
#      'erkennen': 1,
#      'fortgewachen': 1,
#      'besprechen': 1,
#      'ostertage': 1,
#      'erlauben': 1,
#      'andre': 1,
#      'frage': 1,
#      'eifer': 1,
#      'studie': 1,
#      'beflissen': 1}},
#    'CHOR DER ENGEL.': {'lines': 21,
#     'word_freq': {'christ': 3,
#      'erstanden': 2,
#      'freude': 1,
#      'sterblichen': 1,
#      'verderblichen': 1,
#      'schleichend': 1,
#      'erblichen': 1,
#      'mangel': 1,
#      'umwanden': 1,
#      'selig': 1,
#      'liebende': 1,
#      'betrübend': 1,
#      'heilsam': 1,
#      'übend': 1,
#      'prüfung': 1,
#      'bestehen': 1,
#      'erstand': 1,
#      'verwesung': 1,
#      'schoß': 1,
#      'reißet': 1,
#      'bande': 1,
#      'freudig': 1,
#      'tätig': 1,
#      'preisenden': 1,
#      'lieb': 1,
#      'beweisende': 1,
#      'brüderlich': 1,
#      'speisend': 1,
#      'predigend': 1,
#      'reisend': 1,
#      'wonne': 1,
#      'verheißenden': 1,
#      'meister': 1,
#      'nah': 1}},
#    'CHOR DER WEIBER.': {'lines': 7,
#     'word_freq': {'spezereien': 1,
#      'pflegen': 1,
#      'treu': 1,
#      'tücher': 1,
#      'binden': 1,
#      'reinlich': 1,
#      'umwanden': 1,
#      'finden': 1,
#      'christ': 1}},
#    'CHOR DER JÜNGER.': {'lines': 11,
#     'word_freq': {'begrabene': 1,
#      'lebend': 1,
#      'erhabene': 1,
#      'herrlich': 1,
#      'erheben': 1,
#      'schaffend': 1,
#      'freude': 1,
#      'nah': 1,
#      'erde': 1,
#      'brust': 1,
#      'leide': 1,
#      'ließ': 1,
#      'schmachtend': 1,
#      'beweinen': 1,
#      'meister': 1,
#      'glück': 1}}}},
#  {'scene_num': 3,
#   'scene_title': 'Vor dem Tor.',
#   'speakers': {'EINIGE HANDWERKSBURSCHEN.': {'lines': 1,
#     'word_freq': {'hinaus': 1}},
#    'ANDRE.': {'lines': 4,
#     'word_freq': {'gehn': 1,
#      'hinaus': 1,
#      'jägerhaus': 1,
#      'finden': 1,
#      'gewiß': 1,
#      'pappel': 1,
#      'stehen': 1,
#      'heut': 1,
#      'sicher': 1,
#      'krauskopf': 1,
#      'sagen': 1}},
#    'DIE ERSTEN.': {'lines': 1, 'word_freq': {'mühle': 1, 'wandern': 1}},
#    'EIN HANDWERKSBURSCH.': {'lines': 1,
#     'word_freq': {'rat': 1, 'wasserhof': 1, 'gehn': 1}},
#    'ZWEITER.': {'lines': 1, 'word_freq': {'weg': 1, 'schön': 1}},
#    'DIE ZWEITEN.': {'lines': 1, 'word_freq': {}},
#    'EIN DRITTER.': {'lines': 1, 'word_freq': {'anderer': 1}},
#    'VIERTER.': {'lines': 3,
#     'word_freq': {'burgdorf': 1,
#      'herauf': 1,
#      'gewiß': 1,
#      'finden': 1,
#      'schön': 1,
#      'mädchen': 1,
#      'bier': 1,
#      'händel': 1,
#      'sorte': 1}},
#    'FÜNFTER.': {'lines': 3,
#     'word_freq': {'überlustig': 1,
#      'gesell': 1,
#      'juckt': 1,
#      'drittenmal': 1,
#      'fell': 1,
#      'graut': 1,
#      'ort': 1}},
#    'DIENSTMÄDCHEN.': {'lines': 1, 'word_freq': {'stadt': 1}},
#    'ERSTE.': {'lines': 4,
#     'word_freq': {'glück': 1,
#      'seite': 1,
#      'tanzen': 1,
#      'plan': 1,
#      'gehn': 1,
#      'freude': 1}},
#    'SCHÜLER.': {'lines': 4,
#     'word_freq': {'blitz': 1,
#      'wackern': 1,
#      'dirn': 1,
#      'schreiten': 1,
#      'herr': 1,
#      'bruder': 1,
#      'begleiten': 1,
#      'stark': 1,
#      'bier': 1,
#      'beizend': 1,
#      'toback': 1,
#      'magd': 1,
#      'putz': 1,
#      'geschmack': 1}},
#    'BÜRGERMÄDCHEN.': {'lines': 8,
#     'word_freq': {'sieh': 1,
#      'schön': 1,
#      'knabe': 1,
#      'wahrhaftig': 1,
#      'schmach': 1,
#      'gesellschaft': 1,
#      'allerbeste': 1,
#      'laufen': 1,
#      'mägde': 1,
#      'agathe': 1,
#      'fort': 1,
#      'nehmen': 1,
#      'hexe': 1,
#      'öffentlich': 1,
#      'lassen': 1,
#      'sankt': 1,
#      'andreas': 1,
#      'nacht': 1,
#      'liebst': 1,
#      'leiblich': 1,
#      'sehen': 1}},
#    'ZWEITER SCHÜLER': {'lines': 6,
#     'word_freq': {'geschwind': 1,
#      'hinten': 1,
#      'niedlich': 1,
#      'anziehen': 1,
#      'nachbarin': 1,
#      'mädchen': 1,
#      'gewogen': 1,
#      'still': 1,
#      'schritt': 1,
#      'nehmen': 1}},
#    'ERSTER.': {'lines': 4,
#     'word_freq': {'herr': 1,
#      'bruder': 1,
#      'niern': 1,
#      'geschwind': 1,
#      'wildbret': 1,
#      'verlieren': 1,
#      'hand': 1,
#      'samstag': 1,
#      'besen': 1,
#      'führen': 1,
#      'sonntags': 1,
#      'karessieren': 1}},
#    'BÜRGER.': {'lines': 6,
#     'word_freq': {'fällen': 1,
#      'neu': 1,
#      'burgemeister': 1,
#      'täglich': 1,
#      'dreister': 1,
#      'stadt': 1,
#      'schlimm': 1,
#      'gehorche': 1,
#      'zahlen': 1,
#      'vorher': 1}},
#    'BETTLER': {'lines': 7,
#     'word_freq': {'herr': 1,
#      'schön': 1,
#      'frau': 1,
#      'wohlgeputzt': 1,
#      'backenrot': 1,
#      'belieb': 1,
#      'anschauen': 1,
#      'sehen': 1,
#      'mildern': 1,
#      'not': 1,
#      'lassen': 1,
#      'vergebens': 1,
#      'leiern': 1,
#      'mensch': 1,
#      'feiern': 1,
#      'erntetag': 1}},
#    'ANDRER BÜRGER.': {'lines': 8,
#     'word_freq': {'wissen': 1,
#      'feiertag': 1,
#      'gespräch': 1,
#      'krieg': 1,
#      'kriegsgeschrei': 1,
#      'hinten': 1,
#      'türkei': 1,
#      'volk': 1,
#      'schlagen': 1,
#      'stehen': 1,
#      'fenster': 1,
#      'trinken': 1,
#      'gläschen': 1,
#      'sehen': 1,
#      'fluß': 1,
#      'hinab': 1,
#      'bunt': 1,
#      'schiff': 1,
#      'gleiten': 1,
#      'kehren': 1,
#      'abends': 1,
#      'froh': 1,
#      'haus': 1,
#      'segnen': 1,
#      'fried': 1,
#      'friedenszeit': 1}},
#    'DRITTER BÜRGER.': {'lines': 4,
#     'word_freq': {'herr': 1,
#      'nachbar': 1,
#      'laß': 1,
#      'geschehn': 1,
#      'kopf': 1,
#      'spalten': 1,
#      'gehn': 1,
#      'haus': 1,
#      'alt': 1}},
#    'ALTE': {'lines': 4,
#     'word_freq': {'ei': 1,
#      'putzen': 1,
#      'schön': 1,
#      'jung': 1,
#      'blut': 1,
#      'vergaffen': 1,
#      'stolz': 1,
#      'wünschen': 1,
#      'wüßen': 1,
#      'schaffen': 1}},
#    'DIE ANDRE.': {'lines': 4,
#     'word_freq': {'zeigen': 1,
#      'kristall': 1,
#      'soldatenhaft': 1,
#      'mehrere': 1,
#      'verwegn': 1,
#      'seh': 1,
#      'such': 1,
#      'überall': 1,
#      'begegnen': 1}},
#    'SOLDATEN.': {'lines': 18,
#     'word_freq': {'burg': 2,
#      'mädchen': 2,
#      'kühn': 2,
#      'mühen': 2,
#      'herrlich': 2,
#      'lohn': 2,
#      'mauer': 1,
#      'zinne': 1,
#      'stolz': 1,
#      'höhnenden': 1,
#      'sinn': 1,
#      'möcht': 1,
#      'gewinnen': 1,
#      'lassen': 1,
#      'werben': 1,
#      'freude': 1,
#      'verderben': 1,
#      'stürmen': 1,
#      'leben': 1,
#      'geben': 1,
#      'soldat': 1,
#      'ziehe': 1}},
#    'FAUST.': {'lines': 137,
#     'word_freq': {'o': 5,
#      'berg': 4,
#      'himmel': 4,
#      'streben': 3,
#      'bunt': 3,
#      'anderer': 3,
#      'neu': 3,
#      'geist': 3,
#      'strom': 2,
#      'streifen': 2,
#      'farbe': 2,
#      'nehmen': 2,
#      'mensch': 2,
#      'herr': 2,
#      'nacht': 2,
#      'sieh': 2,
#      'menge': 2,
#      'pfad': 2,
#      'hinauf': 2,
#      'unsr': 2,
#      'quälen': 2,
#      'pest': 2,
#      'kreis': 2,
#      'schwarz': 2,
#      'geben': 2,
#      'meer': 2,
#      'wissen': 2,
#      'brauchen': 2,
#      'schön': 2,
#      'betracht': 2,
#      'eilen': 2,
#      'leben': 2,
#      'flügel': 2,
#      'heben': 2,
#      'welt': 2,
#      'fuß': 2,
#      'scheinen': 2,
#      'gesellen': 2,
#      'nah': 2,
#      'ziehen': 2,
#      'eise': 1,
#      'befreien': 1,
#      'bach': 1,
#      'frühling': 1,
#      'holden': 1,
#      'belebend': 1,
#      'blick': 1,
#      'tale': 1,
#      'grünet': 1,
#      'hoffnungsglück': 1,
#      'alt': 1,
#      'winter': 1,
#      'schwäche': 1,
#      'zog': 1,
#      'rauh': 1,
#      'dorther': 1,
#      'senden': 1,
#      'fliehend': 1,
#      'ohnmächtig': 1,
#      'schauer': 1,
#      'körnig': 1,
#      'eis': 1,
#      'grünend': 1,
#      'flur': 1,
#      'sonne': 1,
#      'dulden': 1,
#      'weißes': 1,
#      'überall': 1,
#      'regen': 1,
#      'bildung': 1,
#      'beleben': 1,
#      'blume': 1,
#      'revier': 1,
#      'geputzt': 1,
#      'kehre': 1,
#      'höhe': 1,
#      'stadt': 1,
#      'zurückzusehen': 1,
#      'hohl': 1,
#      'finstern': 1,
#      'tor': 1,
#      'dringt': 1,
#      'gewimmel': 1,
#      'hervor': 1,
#      'sonnen': 1,
#      'feiern': 1,
#      'auferstehung': 1,
#      'selber': 1,
#      'auferstanden': 1,
#      'niedrig': 1,
#      'haus': 1,
#      'dumpf': 1,
#      'gemächern': 1,
#      'gewerbesbande': 1,
#      'druck': 1,
#      'giebel': 1,
#      'dach': 1,
#      'straße': 1,
#      'quetschend': 1,
#      'enge': 1,
#      'kirche': 1,
#      'ehrwürdig': 1,
#      'behend': 1,
#      'garten': 1,
#      'feld': 1,
#      'zerschlägen': 1,
#      'fluß': 1,
#      'breit': 1,
#      'länge': 1,
#      'lustig': 1,
#      'bewegen': 1,
#      'sinken': 1,
#      'überladen': 1,
#      'entfernt': 1,
#      'letzter': 1,
#      'kahn': 1,
#      'fern': 1,
#      'blink': 1,
#      'farbig': 1,
#      'kleid': 1,
#      'hören': 1,
#      'dorf': 1,
#      'getümmel': 1,
#      'volk': 1,
#      'zufrieden': 1,
#      'jauchzet': 1,
#      'klein': 1,
#      'erquickungstrank': 1,
#      'erwidr': 1,
#      'heil': 1,
#      'droben': 1,
#      'stehen': 1,
#      'bücken': 1,
#      'helfen': 1,
#      'lehren': 1,
#      'hilfe': 1,
#      'schicken': 1,
#      'schritt': 1,
#      'stein': 1,
#      'wandrung': 1,
#      'rasen': 1,
#      'sitzen': 1,
#      'gedankenvoll': 1,
#      'bete': 1,
#      'fast': 1,
#      'hoffnung': 1,
#      'reich': 1,
#      'glaube': 1,
#      'fest': 1,
#      'träne': 1,
#      'seufz': 1,
#      'händering': 1,
#      'dacht': 1,
#      'erzwingen': 1,
#      'beifall': 1,
#      'tönen': 1,
#      'hohn': 1,
#      'könntest': 1,
#      'innere': 1,
#      'lesen': 1,
#      'vater': 1,
#      'sohn': 1,
#      'solch': 1,
#      'ruhm': 1,
#      'wert': 1,
#      'natur': 1,
#      'redlichkeit': 1,
#      'weise': 1,
#      'grillenhaft': 1,
#      'mühe': 1,
#      'sinnen': 1,
#      'gesellschaft': 1,
#      'adept': 1,
#      'küche': 1,
#      'schließen': 1,
#      'unendlich': 1,
#      'rezepten': 1,
#      'widrige': 1,
#      'zusammengoß': 1,
#      'rot': 1,
#      'leu': 1,
#      'kühn': 1,
#      'freier': 1,
#      'lau': 1,
#      'bad': 1,
#      'lilie': 1,
#      'vermählen': 1,
#      'offn': 1,
#      'flammenfeuer': 1,
#      'brautgemach': 1,
#      'erschien': 1,
#      'jung': 1,
#      'königin': 1,
#      'glas': 1,
#      'arzenei': 1,
#      'patient': 1,
#      'sterben': 1,
#      'fragen': 1,
#      'genas': 1,
#      'höllisch': 1,
#      'latwerg': 1,
#      'täler': 1,
#      'schlimm': 1,
#      'toben': 1,
#      'gift': 1,
#      'tausend': 1,
#      'welkn': 1,
#      'erleben': 1,
#      'frech': 1,
#      'mörder': 1,
#      'loben': 1,
#      'glücklich': 1,
#      'hoffen': 1,
#      'irrtum': 1,
#      'aufzutauchen': 1,
#      'laß': 1,
#      'stunde': 1,
#      'trübsinn': 1,
#      'verkümmern': 1,
#      'abendsonneglut': 1,
#      'grünumgebn': 1,
#      'hütte': 1,
#      'schimmern': 1,
#      'fördern': 1,
#      'boden': 1,
#      'säh': 1,
#      'ewig': 1,
#      'abendstrahl': 1,
#      'still': 1,
#      'entzünden': 1,
#      'höhn': 1,
#      'beruhigen': 1,
#      'tal': 1,
#      'silberbach': 1,
#      'goldne': 1,
#      'fließen': 1,
#      'hemmen': 1,
#      'göttergleich': 1,
#      'lauf': 1,
#      'wild': 1,
#      'schlucht': 1,
#      'erwärmt': 1,
#      'bucht': 1,
#      'erstaunt': 1,
#      'auge': 1,
#      'göttin': 1,
#      'wegzusinken': 1,
#      'trieb': 1,
#      'erwachen': 1,
#      'fort': 1,
#      'licht': 1,
#      'trinken': 1,
#      'welle': 1,
#      'traum': 1,
#      'indessen': 1,
#      'entweichen': 1,
#      'flügeln': 1,
#      'körperlich': 1,
#      'eingeboren': 1,
#      'gefühl': 1,
#      'vorwärts': 1,
#      'dringen': 1,
#      'blau': 1,
#      'raum': 1,
#      'verlieren': 1,
#      'schmetternd': 1,
#      'lied': 1,
#      'lerche': 1,
#      'singen': 1,
#      'schroff': 1,
#      'fichtenhöhe': 1,
#      'adler': 1,
#      'ausbreiten': 1,
#      'schweben': 1,
#      'fläche': 1,
#      'see': 1,
#      'kranich': 1,
#      'heimat': 1,
#      'triebs': 1,
#      'bewußt': 1,
#      'lerne': 1,
#      'kennen': 1,
#      'seele': 1,
#      'wohnen': 1,
#      'brust': 1,
#      'trennen': 1,
#      'halten': 1,
#      'derber': 1,
#      'liebeslust': 1,
#      'klammernd': 1,
#      'organ': 1,
#      'andre': 1,
#      'gewaltsam': 1,
#      'dunst': 1,
#      'gefilde': 1,
#      'ahn': 1,
#      'luft': 1,
#      'erd': 1,
#      'herrschend': 1,
#      'weben': 1,
#      'steiget': 1,
#      'nieder': 1,
#      'goldn': 1,
#      'duft': 1,
#      'führen': 1,
#      'weg': 1,
#      'zaubermantel': 1,
#      'trüg': 1,
#      'fremd': 1,
#      'land': 1,
#      'köstlichst': 1,
#      'gewänd': 1,
#      'feil': 1,
#      'königsmantel': 1,
#      'siehst': 1,
#      'hund': 1,
#      'saat': 1,
#      'stoppel': 1,
#      'hältst': 1,
#      'tier': 1,
#      'bemerkst': 1,
#      'schneckenkreise': 1,
#      'jagen': 1,
#      'irr': 1,
#      'feuerstrudel': 1,
#      'hinterdrein': 1,
#      'magisch': 1,
#      'leiser': 1,
#      'schling': 1,
#      'band': 1,
#      'eng': 1,
#      'komm': 1,
#      'finden': 1,
#      'spur': 1,
#      'dressur': 1}},
#    'WAGNER.': {'lines': 108,
#     'word_freq': {'juchhe': 6,
#      'juchheisa': 4,
#      'heisa': 4,
#      'he': 4,
#      'mann': 4,
#      'sehen': 4,
#      'herr': 3,
#      'tanzen': 3,
#      'fiedel': 2,
#      'linde': 2,
#      'fiedelbog': 2,
#      'heran': 2,
#      'fliegen': 2,
#      'arm': 2,
#      'o': 2,
#      'ziehen': 2,
#      'vater': 2,
#      'feld': 2,
#      'buch': 2,
#      'blatt': 2,
#      'himmel': 2,
#      'glut': 2,
#      'bringen': 2,
#      'pudel': 2,
#      'doktor': 1,
#      'spazieren': 1,
#      'ehrenvoll': 1,
#      'gewinn': 1,
#      'würd': 1,
#      'verlieren': 1,
#      'feind': 1,
#      'roh': 1,
#      'schreien': 1,
#      'kegelschiebe': 1,
#      'verhaßt': 1,
#      'klang': 1,
#      'toben': 1,
#      'böse': 1,
#      'geist': 1,
#      'treiben': 1,
#      'freude': 1,
#      'gesang': 1,
#      'schäfer': 1,
#      'putzen': 1,
#      'tanz': 1,
#      'bunt': 1,
#      'jacke': 1,
#      'band': 1,
#      'kranz': 1,
#      'schmuck': 1,
#      'anziehen': 1,
#      'voll': 1,
#      'toll': 1,
#      'drücken': 1,
#      'hastig': 1,
#      'stoßen': 1,
#      'mädchen': 1,
#      'ellenbogen': 1,
#      'frisch': 1,
#      'dirne': 1,
#      'kehren': 1,
#      'sagen': 1,
#      'find': 1,
#      'dumm': 1,
#      'ungezogen': 1,
#      'hurtig': 1,
#      'kreis': 1,
#      'rechts': 1,
#      'links': 1,
#      'röck': 1,
#      'rot': 1,
#      'warm': 1,
#      'ruhten': 1,
#      'atmend': 1,
#      'hüft': 1,
#      'ellenbog': 1,
#      'tu': 1,
#      'vertraut': 1,
#      'braut': 1,
#      'belog': 1,
#      'betrügen': 1,
#      'schmeichelen': 1,
#      'scholl': 1,
#      'geschrei': 1,
#      'welch': 1,
#      'gefühl': 1,
#      'mußt': 1,
#      'verehrung': 1,
#      'menge': 1,
#      'glücklich': 1,
#      'gabe': 1,
#      'solch': 1,
#      'vorteil': 1,
#      'zeigen': 1,
#      'knabe': 1,
#      'fragen': 1,
#      'drängen': 1,
#      'eilen': 1,
#      'stocken': 1,
#      'tänzer': 1,
#      'weilen': 1,
#      'reihe': 1,
#      'stehen': 1,
#      'mütze': 1,
#      'höh': 1,
#      'fehlen': 1,
#      'beugen': 1,
#      'knie': 1,
#      'käm': 1,
#      'venerabil': 1,
#      'betrüben': 1,
#      'tut': 1,
#      'brav': 1,
#      'kunst': 1,
#      'übertragen': 1,
#      'gewissenhaft': 1,
#      'pünktlich': 1,
#      'ausüben': 1,
#      'jüngling': 1,
#      'ehrst': 1,
#      'empfangen': 1,
#      'wissenschaft': 1,
#      'vermehrsen': 1,
#      'sohn': 1,
#      'höhr': 1,
#      'ziel': 1,
#      'gelangen': 1,
#      'grillenhaft': 1,
#      'stunde': 1,
#      'trieb': 1,
#      'hab': 1,
#      'empfinden': 1,
#      'wald': 1,
#      'vogel': 1,
#      'fittich': 1,
#      'beneiden': 1,
#      'tragen': 1,
#      'geistesfreude': 1,
#      'winternächt': 1,
#      'hold': 1,
#      'schön': 1,
#      'selig': 1,
#      'leben': 1,
#      'smetin': 1,
#      'glied': 1,
#      'entrollst': 1,
#      'würdig': 1,
#      'pergam': 1,
#      'steigen': 1,
#      'nieder': 1,
#      'beruf': 1,
#      'wohlbekannt': 1,
#      'schar': 1,
#      'strömend': 1,
#      'dunstkreis': 1,
#      'überbreiten': 1,
#      'mensch': 1,
#      'tausendfältig': 1,
#      'gefahr': 1,
#      'bereiten': 1,
#      'norden': 1,
#      'dringen': 1,
#      'scharf': 1,
#      'geisterzahn': 1,
#      'herbei': 1,
#      'pfeilgespitzt': 1,
#      'zunge': 1,
#      'ziehn': 1,
#      'vertrocknend': 1,
#      'nähren': 1,
#      'lung': 1,
#      'mittag': 1,
#      'wüste': 1,
#      'schicken': 1,
#      'scheitel': 1,
#      'häufen': 1,
#      'west': 1,
#      'schwarm': 1,
#      'erquickt': 1,
#      'aue': 1,
#      'ersäufen': 1,
#      'hören': 1,
#      'schaden': 1,
#      'froh': 1,
#      'wenden': 1,
#      'gehorch': 1,
#      'betragen': 1,
#      'stellen': 1,
#      'gesandt': 1,
#      'lispeln': 1,
#      'englisch': 1,
#      'lügen': 1,
#      'ergraut': 1,
#      'welt': 1,
#      'luft': 1,
#      'kühlen': 1,
#      'nebel': 1,
#      'fallen': 1,
#      'abend': 1,
#      'schätzen': 1,
#      'haus': 1,
#      'stehsen': 1,
#      'blickst': 1,
#      'erstaunt': 1,
#      'hinaus': 1,
#      'dämmrung': 1,
#      'ergreifen': 1,
#      'wichtig': 1,
#      'scheinen': 1,
#      'weise': 1,
#      'spur': 1,
#      'plagen': 1,
#      'schwarz': 1,
#      'augentäuschung': 1,
#      'seh': 1,
#      'ungewiß': 1,
#      'furchtsam': 1,
#      'umspringen': 1,
#      'unbekannte': 1,
#      'siehen': 1,
#      'hund': 1,
#      'gespenst': 1,
#      'knurren': 1,
#      'zweifeln': 1,
#      'legen': 1,
#      'bauch': 1,
#      'wedeln': 1,
#      'hundebrauch': 1,
#      'pudelnärrisch': 1,
#      'tier': 1,
#      'stehest': 1,
#      'still': 1,
#      'warten': 1,
#      'sprichsten': 1,
#      'streben': 1,
#      'hinauf': 1,
#      'verliere': 1,
#      'stock': 1,
#      'wasser': 1,
#      'springen': 1,
#      'hunde': 1,
#      'weis': 1,
#      'gewogen': 1,
#      'gunst': 1,
#      'verdienen': 1,
#      'student': 1,
#      'trefflich': 1,
#      'skolar': 1}},
#    'ALTER BAUER.': {'lines': 23,
#     'word_freq': {'schön': 2,
#      'euer': 2,
#      'helfer': 2,
#      'herr': 1,
#      'doktor': 1,
#      'verschmähen': 1,
#      'volksgedräng': 1,
#      'hochgelahrter': 1,
#      'nehmet': 1,
#      'krug': 1,
#      'frisch': 1,
#      'trunk': 1,
#      'füllen': 1,
#      'bring': 1,
#      'wünschen': 1,
#      'laut': 1,
#      'durst': 1,
#      'stillen': 1,
#      'zahl': 1,
#      'tropfen': 1,
#      'hegen': 1,
#      'zulegen': 1,
#      'fürwahr': 1,
#      'froh': 1,
#      'erscheinen': 1,
#      'vormals': 1,
#      'böse': 1,
#      'vater': 1,
#      'zuletzt': 1,
#      'heiß': 1,
#      'fieberwut': 1,
#      'entreißen': 1,
#      'seuch': 1,
#      'ziel': 1,
#      'setzen': 1,
#      'jung': 1,
#      'mann': 1,
#      'gingt': 1,
#      'krankenhaus': 1,
#      'leiche': 1,
#      'tragen': 1,
#      'fort': 1,
#      'kamt': 1,
#      'gesund': 1,
#      'heraus': 1,
#      'bestanden': 1,
#      'hart': 1,
#      'probe': 1,
#      'helfen': 1,
#      'droben': 1}},
#    'ALLE.': {'lines': 2,
#     'word_freq': {'gesundheit': 1, 'bewährt': 1, 'mann': 1, 'helfen': 1}}}},
#  {'scene_num': 4,
#   'scene_title': 'Studierzimmer.',
#   'speakers': {'FAUST': {'lines': 82,
#     'word_freq': {'pudel': 5,
#      'anfang': 4,
#      'hab': 2,
#      'rennen': 2,
#      'zelle': 2,
#      'brennen': 2,
#      'busen': 2,
#      'sehnen': 2,
#      'leben': 2,
#      'heilig': 2,
#      'hund': 2,
#      'schätzen': 2,
#      'geschrieben': 2,
#      'stehen': 2,
#      'helfen': 2,
#      'geist': 2,
#      'sinn': 2,
#      'laß': 2,
#      'sehen': 2,
#      'verlassen': 1,
#      'feld': 1,
#      'auen': 1,
#      'tief': 1,
#      'nacht': 1,
#      'bedeckt': 1,
#      'ahnungsvoll': 1,
#      'grauen': 1,
#      'beßre': 1,
#      'seele': 1,
#      'wecken': 1,
#      'ungestüm': 1,
#      'regeen': 1,
#      'menschenlieb': 1,
#      'liebe': 1,
#      'gott': 1,
#      'regen': 1,
#      'ruhig': 1,
#      'wider': 1,
#      'schwelle': 1,
#      'schnoperen': 1,
#      'lege': 1,
#      'ofen': 1,
#      'nieder': 1,
#      'bestes': 1,
#      'kissen': 1,
#      'geb': 1,
#      'draußen': 1,
#      'bergig': 1,
#      'weg': 1,
#      'spring': 1,
#      'ergetzen': 1,
#      'nimm': 1,
#      'pflege': 1,
#      'willkommn': 1,
#      'still': 1,
#      'gast': 1,
#      'unsr': 1,
#      'eng': 1,
#      'lampe': 1,
#      'freundlich': 1,
#      'unserm': 1,
#      'hellen': 1,
#      'herzen': 1,
#      'selber': 1,
#      'kennen': 1,
#      'vernunft': 1,
#      'fangen': 1,
#      'sprechen': 1,
#      'hoffnung': 1,
#      'blühn': 1,
#      'bächen': 1,
#      'quelle': 1,
#      'knurre': 1,
#      'tön': 1,
#      'seel': 1,
#      'umfassen': 1,
#      'tierisch': 1,
#      'laut': 1,
#      'passen': 1,
#      'wohnen': 1,
#      'mensch': 1,
#      'verhöhnen': 1,
#      'verstehn': 1,
#      'schöne': 1,
#      'beschwerlich': 1,
#      'murren': 1,
#      'beknurren': 1,
#      'fühl': 1,
#      'wille': 1,
#      'befriedigung': 1,
#      'quillen': 1,
#      'strom': 1,
#      'versiegen': 1,
#      'durste': 1,
#      'liegen': 1,
#      'erfahrung': 1,
#      'mangel': 1,
#      'lassen': 1,
#      'ersetzen': 1,
#      'lernen': 1,
#      'überirdische': 1,
#      'offenbarung': 1,
#      'nirgends': 1,
#      'schön': 1,
#      'grundtext': 1,
#      'aufzuschlagen': 1,
#      'redlich': 1,
#      'gefühl': 1,
#      'original': 1,
#      'geliebt': 1,
#      'deutsch': 1,
#      'übertragen': 1,
#      'stock': 1,
#      'fort': 1,
#      'wort': 1,
#      'unmöglich': 1,
#      'übersetzen': 1,
#      'erleuchten': 1,
#      'bedenke': 1,
#      'zeile': 1,
#      'feder': 1,
#      'übereilen': 1,
#      'wirken': 1,
#      'schaffen': 1,
#      'stehn': 1,
#      'kraft': 1,
#      'niederschreiben': 1,
#      'warnen': 1,
#      'bleiben': 1,
#      'seh': 1,
#      'rat': 1,
#      'schreiben': 1,
#      'getrost': 1,
#      'zimmer': 1,
#      'teilen': 1,
#      'heulen': 1,
#      'belle': 1,
#      'solch': 1,
#      'störend': 1,
#      'geselle': 1,
#      'nähe': 1,
#      'leiden': 1,
#      'meiden': 1,
#      'unger': 1,
#      'heb': 1,
#      'gastrecht': 1,
#      'tür': 1,
#      'frei': 1,
#      'lauf': 1,
#      'geschehen': 1,
#      'schatten': 1,
#      'wirklichkeit': 1,
#      'breit': 1,
#      'heben': 1,
#      'gewalt': 1,
#      'gestalt': 1,
#      'welch': 1,
#      'gespenst': 1,
#      'brachen': 1,
#      'haus': 1,
#      'nilpferd': 1,
#      'o': 1,
#      'gewiß': 1,
#      'halb': 1,
#      'höllenbrut': 1,
#      'salomonis': 1,
#      'schlüssel': 1,
#      'abermals': 1,
#      'betrügen': 1,
#      'verschwindet': 1,
#      'geisterreich': 1,
#      'drang': 1,
#      'traum': 1,
#      'teufel': 1,
#      'vorgelogen': 1,
#      'entspringen': 1}},
#    'GEISTER': {'lines': 12,
#     'word_freq': {'schwebet': 2,
#      'drinnen': 1,
#      'gefangen': 1,
#      'bleibet': 1,
#      'haußen': 1,
#      'folg': 1,
#      'eisen': 1,
#      'fuchs': 1,
#      'zagt': 1,
#      'alt': 1,
#      'höllenluchs': 1,
#      'geben': 1,
#      'wider': 1,
#      'nieder': 1,
#      'losgemacht': 1,
#      'nützen': 1,
#      'lassen': 1,
#      'sitzen': 1,
#      'gefallen': 1}},
#    'FAUST.': {'lines': 93,
#     'word_freq': {'hölle': 3,
#      'tier': 2,
#      'undene': 2,
#      'sylphe': 2,
#      'kennen': 2,
#      'meister': 2,
#      'geist': 2,
#      'incubus': 2,
#      'stark': 2,
#      'wesen': 2,
#      'lesen': 2,
#      'bannen': 2,
#      'vergebens': 2,
#      'erwarte': 2,
#      'nennst': 2,
#      'herr': 2,
#      'stehen': 2,
#      'sohn': 2,
#      'fenster': 2,
#      'sagen': 2,
#      'halten': 2,
#      'begegnen': 1,
#      'brauch': 1,
#      'spruch': 1,
#      'viere': 1,
#      'salamander': 1,
#      'glühen': 1,
#      'winden': 1,
#      'verschwinden': 1,
#      'kobold': 1,
#      'mühen': 1,
#      'element': 1,
#      'kraft': 1,
#      'eigenschaft': 1,
#      'verschwind': 1,
#      'flamme': 1,
#      'salamand': 1,
#      'rauschend': 1,
#      'fließe': 1,
#      'leucht': 1,
#      'bring': 1,
#      'häuslich': 1,
#      'hilfe': 1,
#      'tritt': 1,
#      'hervor': 1,
#      'schluß': 1,
#      'stecken': 1,
#      'liegen': 1,
#      'ruhig': 1,
#      'grinst': 1,
#      'hab': 1,
#      'weh': 1,
#      'hören': 1,
#      'beschwören': 1,
#      'geselle': 1,
#      'flüchtling': 1,
#      'sieh': 1,
#      'zeichen': 1,
#      'beugen': 1,
#      'schwarz': 1,
#      'schar': 1,
#      'schwellen': 1,
#      'borstig': 1,
#      'haar': 1,
#      'verworfnes': 1,
#      'entsproßne': 1,
#      'unausgesprochnen': 1,
#      'himmel': 1,
#      'gegoß': 1,
#      'freventlich': 1,
#      'durchstochn': 1,
#      'ofen': 1,
#      'schwillt': 1,
#      'elefant': 1,
#      'raum': 1,
#      'füllen': 1,
#      'nebel': 1,
#      'zerfließen': 1,
#      'steigen': 1,
#      'decke': 1,
#      'hinan': 1,
#      'lege': 1,
#      'fuß': 1,
#      'siehen': 1,
#      'drohen': 1,
#      'versengen': 1,
#      'heilig': 1,
#      'lohe': 1,
#      'dreimal': 1,
#      'glühend': 1,
#      'licht': 1,
#      'künst': 1,
#      'pudel': 1,
#      'kern': 1,
#      'fahrend': 1,
#      'skolast': 1,
#      'casus': 1,
#      'lachen': 1,
#      'gewöhnlich': 1,
#      'name': 1,
#      'allzudeutlich': 1,
#      'weisen': 1,
#      'fliegengott': 1,
#      'verderber': 1,
#      'lügner': 1,
#      'heißen': 1,
#      'rätselwort': 1,
#      'kenn': 1,
#      'deinen': 1,
#      'pflicht': 1,
#      'kannstn': 1,
#      'vernichten': 1,
#      'fängst': 1,
#      'klein': 1,
#      'setzesen': 1,
#      'ewig': 1,
#      'regen': 1,
#      'heilsam': 1,
#      'schaffend': 1,
#      'gewalt': 1,
#      'kalt': 1,
#      'teufelsfaust': 1,
#      'entgegen': 1,
#      'tückisch': 1,
#      'ballen': 1,
#      'suche': 1,
#      'beginnen': 1,
#      'chaos': 1,
#      'wunderlich': 1,
#      'sehen': 1,
#      'fragst': 1,
#      'lernen': 1,
#      'besuch': 1,
#      'türe': 1,
#      'rauchfang': 1,
#      'gewiß': 1,
#      'pentagramma': 1,
#      'pein': 1,
#      'ei': 1,
#      'kamsen': 1,
#      'herein': 1,
#      'betrügen': 1,
#      'zufall': 1,
#      'treffen': 1,
#      'gefangner': 1,
#      'wärst': 1,
#      'ungefähr': 1,
#      'gelingen': 1,
#      'find': 1,
#      'lassen': 1,
#      'pakt': 1,
#      'sicher': 1,
#      'schließen': 1,
#      'bleiben': 1,
#      'augenblick': 1,
#      'mär': 1,
#      'nachgestellen': 1,
#      'garn': 1,
#      'teufel': 1,
#      'mal': 1,
#      'fangen': 1,
#      'seh': 1,
#      'frei': 1,
#      'kunst': 1,
#      'gefällig': 1}},
#    'MEPHISTOPHELES': {'lines': 1,
#     'word_freq': {'wozu': 1, 'lärm': 1, 'stehen': 1, 'herr': 1, 'dienst': 1}},
#    'MEPHISTOPHELES.': {'lines': 102,
#     'word_freq': {'körper': 5,
#      'klein': 3,
#      'stets': 3,
#      'teufel': 3,
#      'herr': 2,
#      'böse': 2,
#      'geist': 2,
#      'zugrunde': 2,
#      'licht': 2,
#      'schön': 2,
#      'bleiben': 2,
#      'meer': 2,
#      'frisch': 2,
#      'fort': 2,
#      'mal': 2,
#      'schwelle': 2,
#      'belieben': 2,
#      'zart': 2,
#      'salutiern': 1,
#      'gelehrt': 1,
#      'weidlich': 1,
#      'schwitzen': 1,
#      'frage': 1,
#      'scheinen': 1,
#      'wort': 1,
#      'verachten': 1,
#      'entfernt': 1,
#      'schein': 1,
#      'wesen': 1,
#      'tiefe': 1,
#      'trachten': 1,
#      'kraft': 1,
#      'schaffen': 1,
#      'verneinen': 1,
#      'entstehen': 1,
#      'wert': 1,
#      'drum': 1,
#      'entstünden': 1,
#      'sünde': 1,
#      'zerstörung': 1,
#      'nennen': 1,
#      'eigentlich': 1,
#      'element': 1,
#      'bescheidne': 1,
#      'wahrheit': 1,
#      'sprech': 1,
#      'mensch': 1,
#      'narrenwelt': 1,
#      'gewöhnlich': 1,
#      'halten': 1,
#      'anfangs': 1,
#      'finsternis': 1,
#      'gebar': 1,
#      'stolz': 1,
#      'mutter': 1,
#      'nacht': 1,
#      'alt': 1,
#      'rang': 1,
#      'raum': 1,
#      'streitig': 1,
#      'streben': 1,
#      'verhaften': 1,
#      'kleben': 1,
#      'gange': 1,
#      'hoff': 1,
#      'dauern': 1,
#      'gehn': 1,
#      'freilich': 1,
#      'entgegenstellen': 1,
#      'plump': 1,
#      'welt': 1,
#      'unternehmen': 1,
#      'wissen': 1,
#      'beizukommen': 1,
#      'welle': 1,
#      'stürm': 1,
#      'schütteln': 1,
#      'brand': 1,
#      'geruhig': 1,
#      'land': 1,
#      'verdammt': 1,
#      'zeug': 1,
#      'menschenbrut': 1,
#      'anhaben': 1,
#      'hab': 1,
#      'begraben': 1,
#      'zirkulieren': 1,
#      'neu': 1,
#      'blut': 1,
#      'möchten': 1,
#      'rasend': 1,
#      'luft': 1,
#      'wasser': 1,
#      'erde': 1,
#      'entwind': 1,
#      'tausend': 1,
#      'keim': 1,
#      'trocknen': 1,
#      'feucht': 1,
#      'warm': 1,
#      'kalte': 1,
#      'hätt': 1,
#      'flamm': 1,
#      'vorbehalten': 1,
#      'apart': 1,
#      'besinnen': 1,
#      'nächster': 1,
#      'diesmal': 1,
#      'entfernen': 1,
#      'gesteh': 1,
#      'hinausspazieren': 1,
#      'verbietet': 1,
#      'hindernis': 1,
#      'drudenfuß': 1,
#      'eurer': 1,
#      'beschauen': 1,
#      'ziehen': 1,
#      'winkel': 1,
#      'außen': 1,
#      'siehen': 1,
#      'pudel': 1,
#      'merken': 1,
#      'hereingesprungen': 1,
#      'sache': 1,
#      'sehen': 1,
#      'haus': 1,
#      'gesetz': 1,
#      'gespenster': 1,
#      'hereingeschlüpfen': 1,
#      'hinaus': 1,
#      'stehen': 1,
#      'frei': 1,
#      'knecht': 1,
#      'versprechen': 1,
#      'rein': 1,
#      'genießen': 1,
#      'abzwacken': 1,
#      'fassen': 1,
#      'besprechen': 1,
#      'jetzo': 1,
#      'beten': 1,
#      'höchst': 1,
#      'entlassen': 1,
#      'laß': 1,
#      'fragen': 1,
#      'bereit': 1,
#      'gesellschaft': 1,
#      'bedingnis': 1,
#      'kunst': 1,
#      'würdig': 1,
#      'vertreiben': 1,
#      'freund': 1,
#      'sinn': 1,
#      'stunde': 1,
#      'gewinnen': 1,
#      'einerlei': 1,
#      'singen': 1,
#      'bild': 1,
#      'bringen': 1,
#      'leer': 1,
#      'zauberspiel': 1,
#      'geruch': 1,
#      'ergetzen': 1,
#      'gaumen': 1,
#      'letzen': 1,
#      'entzücken': 1,
#      'gefühl': 1,
#      'bereitung': 1,
#      'brauchen': 1,
#      'voran': 1,
#      'beisamme': 1,
#      'fanget': 1,
#      'schlafen': 1,
#      'junge': 1,
#      'treulich': 1,
#      'eingesungen': 1,
#      'konzert': 1,
#      'eur': 1,
#      'schuld': 1,
#      'mann': 1,
#      'festhalten': 1,
#      'umgaukelt': 1,
#      'süß': 1,
#      'traumgestalt': 1,
#      'versenken': 1,
#      'wahn': 1,
#      'bedarf': 1,
#      'rattenzahn': 1,
#      'brauch': 1,
#      'beschwören': 1,
#      'raschelen': 1,
#      'sogleich': 1,
#      'hören': 1,
#      'ratte': 1,
#      'maus': 1,
#      'fliege': 1,
#      'frösche': 1,
#      'wanz': 1,
#      'laus': 1,
#      'befiehlt': 1,
#      'hervorzuwagen': 1,
#      'benagen': 1,
#      'öl': 1,
#      'betupfen': 1,
#      'kommsen': 1,
#      'hervorgehupfen': 1,
#      'werk': 1,
#      'spitze': 1,
#      'bannen': 1,
#      'sitzen': 1,
#      'vornen': 1,
#      'kante': 1,
#      'biß': 1,
#      'geschehn': 1,
#      'fauste': 1,
#      'träume': 1,
#      'wiedersehn': 1}},
#    'GEISTER.': {'lines': 58,
#     'word_freq': {'laube': 3,
#      'dunkeln': 2,
#      'schauen': 2,
#      'decke': 2,
#      'leben': 2,
#      'höhe': 2,
#      'see': 2,
#      'flieget': 2,
#      'anderer': 2,
#      'schwindet': 1,
#      'wölbunge': 1,
#      'droben': 1,
#      'reizender': 1,
#      'freundlich': 1,
#      'blau': 1,
#      'äther': 1,
#      'herein': 1,
#      'wären': 1,
#      'wolke': 1,
#      'zerronnen': 1,
#      'sternelein': 1,
#      'funkeln': 1,
#      'mildere': 1,
#      'sonn': 1,
#      'scheinen': 1,
#      'darein': 1,
#      'himmlischer': 1,
#      'sohn': 1,
#      'geistige': 1,
#      'schön': 1,
#      'schwankend': 1,
#      'beugung': 1,
#      'schwebet': 1,
#      'vorüber': 1,
#      'sehnende': 1,
#      'neigung': 1,
#      'folget': 1,
#      'hinüber': 1,
#      'gewänder': 1,
#      'flatternd': 1,
#      'band': 1,
#      'land': 1,
#      'tief': 1,
#      'gedanke': 1,
#      'liebende': 1,
#      'geben': 1,
#      'sprossend': 1,
#      'ranke': 1,
#      'lastend': 1,
#      'traube': 1,
#      'drängender': 1,
#      'kelter': 1,
#      'sturz': 1,
#      'bach': 1,
#      'schäumend': 1,
#      'wein': 1,
#      'riesel': 1,
#      'rein': 1,
#      'edle': 1,
#      'gesteine': 1,
#      'lassen': 1,
#      'liegen': 1,
#      'breite': 1,
#      'genügen': 1,
#      'grünender': 1,
#      'hügel': 1,
#      'geflügel': 1,
#      'schlürfet': 1,
#      'wonne': 1,
#      'sonne': 1,
#      'hell': 1,
#      'insel': 1,
#      'entgegen': 1,
#      'welle': 1,
#      'gauklend': 1,
#      'bewegen': 1,
#      'chör': 1,
#      'jauchzend': 1,
#      'hören': 1,
#      'auen': 1,
#      'tanzend': 1,
# ...
#      'geben': 1,
#      'althier': 1,
#      'brauch': 1,
#      'schreiben': 1,
#      'verzeiht': 1,
#      'herr': 1,
#      'verschwinden': 1,
#      'vorhang': 1,
#      'aufzuziehn': 1}}}},
#  {'scene_num': 23,
#   'scene_title': 'Walpurgisnachtstraum',
#   'speakers': {'THEATERMEISTER.': {'lines': 4,
#     'word_freq': {'ruhen': 1,
#      'mieding': 1,
#      'wackre': 1,
#      'sohn': 1,
#      'alt': 1,
#      'berg': 1,
#      'feucht': 1,
#      'tal': 1,
#      'szene': 1}},
#    'HEROLD.': {'lines': 4,
#     'word_freq': {'golden': 2,
#      'hochzeit': 1,
#      'solln': 1,
#      'funfzig': 1,
#      'vorüber': 1,
#      'streit': 1,
#      'vorbei': 1}},
#    'OBERON.': {'lines': 8,
#     'word_freq': {'geist': 1,
#      'stunde': 1,
#      'könig': 1,
#      'königin': 1,
#      'neu': 1,
#      'verbinden': 1,
#      'gatte': 1,
#      'vertragen': 1,
#      'lieben': 1,
#      'brauchen': 1,
#      'scheiden': 1}},
#    'PUCK.': {'lines': 7,
#     'word_freq': {'puck': 2,
#      'drehen': 1,
#      'quer': 1,
#      'schleifen': 1,
#      'fuß': 1,
#      'reihe': 1,
#      'freuen': 1,
#      'tretet': 1,
#      'mastig': 1,
#      'elefantenkälber': 1,
#      'plumpst': 1,
#      'derbe': 1,
#      'selber': 1}},
#    'ARIEL.': {'lines': 8,
#     'word_freq': {'locken': 2,
#      'ariel': 1,
#      'bewegen': 1,
#      'sang': 1,
#      'himmlisch': 1,
#      'rein': 1,
#      'ton': 1,
#      'vieler': 1,
#      'fratz': 1,
#      'klang': 1,
#      'schöne': 1,
#      'liebend': 1,
#      'natur': 1,
#      'geist': 1,
#      'flügel': 1,
#      'folget': 1,
#      'spur': 1,
#      'rosenhügel': 1}},
#    'TITANIA.': {'lines': 4,
#     'word_freq': {'schmollen': 1,
#      'mann': 1,
#      'grillt': 1,
#      'frau': 1,
#      'fassen': 1,
#      'behend': 1,
#      'führen': 1,
#      'mittag': 1,
#      'norden': 1}},
#    'ORCHESTER TUTTI': {'lines': 4,
#     'word_freq': {'fliegenschnauz': 1,
#      'mückenna': 1,
#      'anverwandt': 1,
#      'frosch': 1,
#      'laub': 1,
#      'grill': 1,
#      'gras': 1,
#      'musikant': 1}},
#    'SOLO.': {'lines': 9,
#     'word_freq': {'geben': 2,
#      'seht': 1,
#      'dudelsack': 1,
#      'seifenblase': 1,
#      'hören': 1,
#      'schneckeschnickeschnack': 1,
#      'stumpf': 1,
#      'nase': 1,
#      'geist': 1,
#      'bildet': 1,
#      'spinnenfuß': 1,
#      'krötenbauch': 1,
#      'flügelchen': 1,
#      'wichtchen': 1,
#      'tierchen': 1,
#      'gedichtchen': 1}},
#    'EIN PÄRCHEN.': {'lines': 4,
#     'word_freq': {'schritt': 1,
#      'sprung': 1,
#      'honigtau': 1,
#      'düfte': 1,
#      'trippelsen': 1,
#      'genung': 1,
#      'lüfte': 1}},
#    'NEUGIERIGER REISENDER.': {'lines': 8,
#     'word_freq': {'schnopern': 2,
#      'auge': 1,
#      'trauen': 1,
#      'oberon': 1,
#      'schön': 1,
#      'gott': 1,
#      'schauen': 1,
#      'heißen': 1,
#      'steif': 1,
#      'mann': 1,
#      'stolz': 1,
#      'schritt': 1,
#      'spüren': 1}},
#    'ORTHODOX.': {'lines': 4,
#     'word_freq': {'klau': 1,
#      'schwanz': 1,
#      'bleiben': 1,
#      'zweifel': 1,
#      'gott': 1,
#      'griechenland': 1,
#      'teufel': 1}},
#    'NORDISCHER KÜNSTLER.': {'lines': 4,
#     'word_freq': {'ergreifen': 1,
#      'heut': 1,
#      'fürwahr': 1,
#      'skizzenweise': 1,
#      'bereiten': 1,
#      'reise': 1}},
#    'PURIST.': {'lines': 4,
#     'word_freq': {'unglück': 1,
#      'führen': 1,
#      'ludern': 1,
#      'hexenheer': 1,
#      'pudern': 1}},
#    'JUNGE HEXE.': {'lines': 4,
#     'word_freq': {'puder': 1,
#      'rock': 1,
#      'alt': 1,
#      'grau': 1,
#      'weibch': 1,
#      'drum': 1,
#      'sitz': 1,
#      'nackt': 1,
#      'bock': 1,
#      'zeig': 1,
#      'derb': 1,
#      'leibchen': 1}},
#    'MATRONE.': {'lines': 4,
#     'word_freq': {'lebensart': 1,
#      'maulen': 1,
#      'hoff': 1,
#      'jung': 1,
#      'zart': 1,
#      'verfaulen': 1}},
#    'KAPELLMEISTER.': {'lines': 8,
#     'word_freq': {'fliegenschnauz': 2,
#      'mückennas': 2,
#      'frosch': 2,
#      'laub': 2,
#      'grill': 2,
#      'gras': 2,
#      'umschwärmt': 1,
#      'nackt': 1,
#      'bleiben': 1,
#      'takt': 1,
#      'verfluchte': 1,
#      'dilettant': 1,
#      'musikant': 1}},
#    'WINDFAHNE': {'lines': 8,
#     'word_freq': {'mann': 2,
#      'gesellschaft': 1,
#      'wünschen': 1,
#      'wahrhaftig': 1,
#      'lauter': 1,
#      'bräute': 1,
#      'junggesellen': 1,
#      'hoffnungsvollst': 1,
#      'leute': 1,
#      'boden': 1,
#      'verschlingen': 1,
#      'behend': 1,
#      'lauf': 1,
#      'hölle': 1,
#      'springen': 1}},
#    'XENIEN.': {'lines': 4,
#     'word_freq': {'insekt': 1,
#      'klein': 1,
#      'scharf': 1,
#      'scher': 1,
#      'satan': 1,
#      'unsern': 1,
#      'herr': 1,
#      'papa': 1,
#      'verehren': 1}},
#    'HENNINGS.': {'lines': 4,
#     'word_freq': {'seht': 1,
#      'gedrängt': 1,
#      'schar': 1,
#      'naiv': 1,
#      'scherzen': 1,
#      'sagen': 1,
#      'herz': 1}},
#    'MUSAGET.': {'lines': 9,
#     'word_freq': {'hexenheer': 1,
#      'verlieren': 1,
#      'freilich': 1,
#      'wüßen': 1,
#      'muse': 1,
#      'anzuführen': 1,
#      'genius': 1,
#      'leute': 1,
#      'komm': 1,
#      'fassen': 1,
#      'zipfel': 1,
#      'blocksberg': 1,
#      'deutsch': 1,
#      'parnaß': 1,
#      'breit': 1,
#      'gipfel': 1}},
#    'KRANICH.': {'lines': 4,
#     'word_freq': {'klar': 1,
#      'trübe': 1,
#      'fischen': 1,
#      'sehen': 1,
#      'fromm': 1,
#      'herr': 1,
#      'teufel': 1,
#      'mischen': 1}},
#    'WELTKIND.': {'lines': 4,
#     'word_freq': {'fromme': 1,
#      'glaubet': 1,
#      'vehikel': 1,
#      'bilden': 1,
#      'blocksberg': 1,
#      'konventikel': 1}},
#    'TÄNZER.': {'lines': 4,
#     'word_freq': {'neu': 1,
#      'chor': 1,
#      'hören': 1,
#      'fern': 1,
#      'trommel': 1,
#      'ungestört': 1,
#      'rohr': 1,
#      'unison': 1,
#      'dommel': 1}},
#    'TANZMEISTER.': {'lines': 4,
#     'word_freq': {'bein': 1,
#      'lupfen': 1,
#      'herausziehen': 1,
#      'krumm': 1,
#      'springen': 1,
#      'plumpe': 1,
#      'hupft': 1,
#      'fragen': 1,
#      'aussehen': 1}},
#    'FIDELER.': {'lines': 4,
#     'word_freq': {'hassen': 1,
#      'schwer': 1,
#      'lumpenpack': 1,
#      'gäb': 1,
#      'restchen': 1,
#      'dudelsack': 1,
#      'orpheu': 1,
#      'leier': 1,
#      'bestje': 1}},
#    'DOGMATIKER.': {'lines': 4,
#     'word_freq': {'teufel': 2,
#      'lassen': 1,
#      'irren': 1,
#      'schrein': 1,
#      'kritik': 1,
#      'zweifel': 1}},
#    'IDEALIST.': {'lines': 3,
#     'word_freq': {'phantasie': 1,
#      'sinn': 1,
#      'diesmal': 1,
#      'herrisch': 1,
#      'närrisch': 1}},
#    'REALIST.': {'lines': 4,
#     'word_freq': {'wesen': 1,
#      'qual': 1,
#      'baß': 1,
#      'verdrießen': 1,
#      'stehen': 1,
#      'mal': 1,
#      'fest': 1,
#      'fuß': 1}},
#    'SUPERNATURALIST.': {'lines': 4,
#     'word_freq': {'vergnügen': 1,
#      'freuen': 1,
#      'teufel': 1,
#      'geist': 1,
#      'schließen': 1}},
#    'SKEPTIKER.': {'lines': 4,
#     'word_freq': {'gehn': 1,
#      'flämmche': 1,
#      'spur': 1,
#      'nah': 1,
#      'schatze': 1,
#      'teufel': 1,
#      'reimen': 1,
#      'zweifel': 1,
#      'platz': 1}},
#    'DIE GEWANDTEN.': {'lines': 4,
#     'word_freq': {'sanssouci': 1,
#      'heißen': 1,
#      'heer': 1,
#      'lustig': 1,
#      'geschöpf': 1,
#      'fuß': 1,
#      'drum': 1,
#      'gehn': 1,
#      'kopf': 1}},
#    'DIE UNBEHÜLFLICHEN.': {'lines': 4,
#     'word_freq': {'biss': 1,
#      'erschranzen': 1,
#      'gott': 1,
#      'befohlen': 1,
#      'schuh': 1,
#      'durchgetanzen': 1,
#      'laufen': 1,
#      'nackt': 1,
#      'sohl': 1}},
#    'IRRLICHTER.': {'lines': 4,
#     'word_freq': {'sumpfe': 1,
#      'woraus': 1,
#      'entstehen': 1,
#      'reihe': 1,
#      'glänzend': 1,
#      'galant': 1}},
#    'STERNSCHNUPPE.': {'lines': 4,
#     'word_freq': {'höhe': 1,
#      'schoßn': 1,
#      'feuerscheine': 1,
#      'lieg': 1,
#      'grase': 1,
#      'quer': 1,
#      'helfen': 1,
#      'bein': 1}},
#    'DIE MASSIVEN.': {'lines': 4,
#     'word_freq': {'platz': 2,
#      'geist': 2,
#      'ringsherum': 1,
#      'gehn': 1,
#      'gräschen': 1,
#      'nieder': 1,
#      'plumpe': 1,
#      'glied': 1}},
#    'ORCHESTER.': {'lines': 4,
#     'word_freq': {'pianissimo': 1,
#      'wolkenzug': 1,
#      'nebelflor': 1,
#      'erhelle': 1,
#      'luft': 1,
#      'laub': 1,
#      'wind': 1,
#      'rohr': 1,
#      'zerstoben': 1}}}},
#  {'scene_num': 24,
#   'scene_title': 'Trüber Tag. Feld.',
#   'speakers': {'FAUST.': {'lines': 3,
#     'word_freq': {'rette': 1,
#      'weh': 1,
#      'gräßlichster': 1,
#      'fluch': 1,
#      'jahrtausend': 1,
#      'bringe': 1,
#      'frei': 1}},
#    'MEPHISTOPHELES.': {'lines': 2, 'word_freq': {'endigst': 1}},
#    'FAUST': {'lines': 0, 'word_freq': {}}}},
#  {'scene_num': 25,
#   'scene_title': 'Nacht. Offen Feld.',
#   'speakers': {'FAUST.': {'lines': 3,
#     'word_freq': {'schweben': 2,
#      'weben': 1,
#      'rabenstein': 1,
#      'neigen': 1,
#      'beugen': 1,
#      'streuen': 1,
#      'weih': 1}},
#    'MEPHISTOPHELES.': {'lines': 3,
#     'word_freq': {'vorbei': 2,
#      'weiße': 1,
#      'kochen': 1,
#      'schaffen': 1,
#      'hexenzunft': 1}}}},
#  {'scene_num': 26,
#   'scene_title': 'Kerker.',
#   'speakers': {'FAUST': {'lines': 23,
#     'word_freq': {'fort': 3,
#      'fassen': 2,
#      'still': 2,
#      'komm': 2,
#      'längst': 1,
#      'entwohnt': 1,
#      'schauer': 1,
#      'menschheit': 1,
#      'jammer': 1,
#      'wohnen': 1,
#      'feucht': 1,
#      'mauer': 1,
#      'verbrechen': 1,
#      'wahn': 1,
#      'zauderst': 1,
#      'fürchtest': 1,
#      'wiederzusehen': 1,
#      'zagen': 1,
#      'zögern': 1,
#      'tod': 1,
#      'heran': 1,
#      'mutter': 1,
#      'hur': 1,
#      'umbringen': 1,
#      'vater': 1,
#      'schelm': 1,
#      'ssen': 1,
#      'schwesterlein': 1,
#      'klein': 1,
#      'hub': 1,
#      'bein': 1,
#      'kühl': 1,
#      'ort': 1,
#      'schön': 1,
#      'waldvögelein': 1,
#      'fliege': 1,
#      'fliegen': 1,
#      'ahnen': 1,
#      'geliebte': 1,
#      'lauscht': 1,
#      'kette': 1,
#      'klirren': 1,
#      'hören': 1,
#      'stroh': 1,
#      'rauscht': 1,
#      'befreien': 1,
#      'liebender': 1,
#      'liegen': 1,
#      'fuß': 1,
#      'jammerknechtschaft': 1,
#      'aufzuschließen': 1,
#      'gretche': 1,
#      'gretchen': 1}},
#    'MARGARETE': {'lines': 33,
#     'word_freq': {'laß': 3,
#      'hab': 3,
#      'weh': 2,
#      'jung': 2,
#      'freund': 2,
#      'liegen': 2,
#      'schwelle': 2,
#      'hölle': 2,
#      'rufen': 2,
#      'bittrer': 1,
#      'tod': 1,
#      'mensch': 1,
#      'fühlen': 1,
#      'not': 1,
#      'henker': 1,
#      'geben': 1,
#      'holst': 1,
#      'mitternacht': 1,
#      'erbarme': 1,
#      'leben': 1,
#      'früh': 1,
#      'zeitig': 1,
#      'genung': 1,
#      'sterben': 1,
#      'schön': 1,
#      'verderben': 1,
#      'nah': 1,
#      'zerrisse': 1,
#      'kranz': 1,
#      'blume': 1,
#      'zerstreuen': 1,
#      'fasse': 1,
#      'gewaltsam': 1,
#      'schone': 1,
#      'vergebens': 1,
#      'flehen': 1,
#      'sehen': 1,
#      'o': 1,
#      'knien': 1,
#      'anrufen': 1,
#      'sieh': 1,
#      'stufe': 1,
#      'siedet': 1,
#      'böse': 1,
#      'furchtbar': 1,
#      'grimme': 1,
#      'getöse': 1,
#      'stimme': 1,
#      'hören': 1,
#      'frei': 1,
#      'wehren': 1,
#      'hals': 1,
#      'fliegen': 1,
#      'busen': 1,
#      'gretchen': 1,
#      'stehen': 1,
#      'mitten': 1,
#      'heulen': 1,
#      'klappe': 1,
#      'grimmig': 1,
#      'teuflisch': 1,
#      'hohn': 1,
#      'erkannt': 1,
#      'süßen': 1,
#      'liebend': 1,
#      'ton': 1,
#      'gewiß': 1}},
#    'FAUST.': {'lines': 24,
#     'word_freq': {'komm': 3,
#      'liebche': 3,
#      'folge': 2,
#      'wächter': 1,
#      'schlafe': 1,
#      'schreien': 1,
#      'werd': 1,
#      'jammer': 1,
#      'überstehen': 1,
#      'eile': 1,
#      'eilest': 1,
#      'teuer': 1,
#      'büßen': 1,
#      'fassen': 1,
#      'mut': 1,
#      'herzen': 1,
#      'tausendfach': 1,
#      'glut': 1,
#      'bitten': 1,
#      'weichen': 1,
#      'tief': 1,
#      'nacht': 1,
#      'laß': 1,
#      'vergangne': 1,
#      'vergehen': 1,
#      'bringstn': 1,
#      'fühlst': 1,
#      'freie': 1,
#      'kannstn': 1,
#      'tür': 1,
#      'stehen': 1,
#      'bleiben': 1,
#      'besinne': 1,
#      'schritt': 1,
#      'frei': 1,
#      'hilft': 1,
#      'flehen': 1,
#      'helfen': 1,
#      'sagen': 1,
#      'wag': 1,
#      'hinweg': 1,
#      'tragen': 1,
#      'graut': 1,
#      'o': 1,
#      'wär': 1,
#      'gebären': 1,
#      'leben': 1}},
#    'MARGARETE.': {'lines': 123,
#     'word_freq': {'mutter': 4,
#      'hab': 4,
#      'fort': 4,
#      'rette': 4,
#      'kind': 3,
#      'o': 3,
#      'grab': 3,
#      'laß': 2,
#      'umbringen': 2,
#      'bös': 2,
#      'sag': 2,
#      'wohin': 2,
#      'retten': 2,
#      'freund': 2,
#      'stumm': 2,
#      'drum': 2,
#      'hand': 2,
#      'lieb': 2,
#      'gott': 2,
#      'mußt': 2,
#      'platz': 2,
#      'heinrich': 2,
#      'elend': 2,
#      'geschwind': 2,
#      'sitzen': 2,
#      'stein': 2,
#      'kopf': 2,
#      'schlief': 2,
#      'heilig': 2,
#      'tränken': 1,
#      'herzen': 1,
#      'nacht': 1,
#      'nehmen': 1,
#      'kränken': 1,
#      'sagen': 1,
#      'hättn': 1,
#      'niemals': 1,
#      'froh': 1,
#      'singen': 1,
#      'lied': 1,
#      'leute': 1,
#      'alt': 1,
#      'märchen': 1,
#      'endigen': 1,
#      'heißen': 1,
#      'deuten': 1,
#      'qual': 1,
#      'angst': 1,
#      'kerker': 1,
#      'kette': 1,
#      'kommst': 1,
#      'straße': 1,
#      'mal': 1,
#      'sehen': 1,
#      'heiter': 1,
#      'garten': 1,
#      'marthe': 1,
#      'warten': 1,
#      'weile': 1,
#      'weilest': 1,
#      'kannstn': 1,
#      'küssen': 1,
#      'entfernt': 1,
#      'küsse': 1,
#      'verlernen': 1,
#      'hals': 1,
#      'bingen': 1,
#      'wort': 1,
#      'blick': 1,
#      'himmel': 1,
#      'überdrang': 1,
#      'küßtesen': 1,
#      'wolltest': 1,
#      'ersticken': 1,
#      'küs': 1,
#      'küss': 1,
#      'lieben': 1,
#      'geblieben': 1,
#      'bringen': 1,
#      'fessel': 1,
#      'nimmst': 1,
#      'schoß': 1,
#      'scheust': 1,
#      'weißen': 1,
#      'befreisen': 1,
#      'ertränken': 1,
#      'schenken': 1,
#      'glaub': 1,
#      'gib': 1,
#      'traum': 1,
#      'feucht': 1,
#      'wische': 1,
#      'deuchen': 1,
#      'blut': 1,
#      'dran': 1,
#      'stecke': 1,
#      'deg': 1,
#      'bitten': 1,
#      'übrigbleiben': 1,
#      'beschreiben': 1,
#      'sorgen': 1,
#      'geben': 1,
#      'bruder': 1,
#      'sogleich': 1,
#      'darneben': 1,
#      'beiseit': 1,
#      'brust': 1,
#      'seite': 1,
#      'schmiegen': 1,
#      'süß': 1,
#      'hold': 1,
#      'glück': 1,
#      'gelingen': 1,
#      'müßt': 1,
#      'zwingen': 1,
#      'stießest': 1,
#      'blickst': 1,
#      'dahinaus': 1,
#      'drauß': 1,
#      'lauert': 1,
#      'tod': 1,
#      'ewig': 1,
#      'ruhebett': 1,
#      'schritt': 1,
#      'gehst': 1,
#      'hoffen': 1,
#      'helfen': 1,
#      'fliehn': 1,
#      'lauern': 1,
#      'betteln': 1,
#      'gewissen': 1,
#      'fremde': 1,
#      'schweifen': 1,
#      'ergreifen': 1,
#      'arm': 1,
#      'weg': 1,
#      'bach': 1,
#      'hinauf': 1,
#      'steg': 1,
#      'wald': 1,
#      'hinein': 1,
#      'links': 1,
#      'planke': 1,
#      'stehen': 1,
#      'teich': 1,
#      'faß': 1,
#      'heben': 1,
#      'zappeln': 1,
#      'wären': 1,
#      'berg': 1,
#      'vorbei': 1,
#      'wackeln': 1,
#      'winken': 1,
#      'nickt': 1,
#      'schwer': 1,
#      'wachen': 1,
#      'freuen': 1,
#      'glücklich': 1,
#      'leiden': 1,
#      'gewalt': 1,
#      'fasse': 1,
#      'mörderisch': 1,
#      'letzter': 1,
#      'dringen': 1,
#      'herein': 1,
#      'hochzeittag': 1,
#      'gretche': 1,
#      'warst': 1,
#      'weh': 1,
#      'kranze': 1,
#      'geschehn': 1,
#      'wiedersehn': 1,
#      'tanze': 1,
#      'menge': 1,
#      'drängen': 1,
#      'hören': 1,
#      'gasse': 1,
#      'fassen': 1,
#      'glocke': 1,
#      'rufen': 1,
#      'stäbchen': 1,
#      'brechen': 1,
#      'binden': 1,
#      'packen': 1,
#      'blutstuhl': 1,
#      'entrückt': 1,
#      'zucken': 1,
#      'nacken': 1,
#      'schärfe': 1,
#      'zückt': 1,
#      'liegen': 1,
#      'welt': 1,
#      'steigen': 1,
#      'boden': 1,
#      'herauf': 1,
#      'schick': 1,
#      'ort': 1,
#      'gericht': 1,
#      'übergeben': 1,
#      'vater': 1,
#      'engel': 1,
#      'schar': 1,
#      'lagert': 1,
#      'umher': 1,
#      'bewahren': 1}},
#    'MEPHISTOPHELES': {'lines': 6,
#     'word_freq': {'verlieren': 1,
#      'unnütz': 1,
#      'zagen': 1,
#      'zaudern': 1,
#      'plaudern': 1,
#      'pferd': 1,
#      'schaudern': 1,
#      'dämmern': 1,
#      'komm': 1,
#      'lassen': 1,
#      'stich': 1}},
#    'MEPHISTOPHELES.': {'lines': 1, 'word_freq': {'richten': 1}},
#    'STIMME': {'lines': 2, 'word_freq': {'heinrich': 2, 'retten': 1}}}}]

# %%
import json

# If you haven't yet, rename the existing stats for book 1:
scene_stats_book1 = scene_stats

# After you load & process book 2 the same way, rename its stats:
# scene_stats_book2 = scene_stats

# Export both to JSON files
for stats, fname in [
    (scene_stats_book1, "book1_scene_stats.json"),
    # (scene_stats_book2, "book2_scene_stats.json"
]:
    with open(fname, "w", encoding="utf-8") as f:
        json.dump(stats, f, ensure_ascii=False, indent=2)

# %%
records = []
for scene in scenes:
    scene_id = scene.get('xml:id')
    for sp in scene.xpath('.//sp'):
        speaker = sp.xpath('./speaker/text()')[0]
        for line in sp.xpath('./l'):
            text = line.text.strip()
            records.append({'scene': scene_id, 'speaker': speaker, 'line': text})
df = pd.DataFrame(records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 9
#       7             text = line.text.strip()
#       8             records.append({'scene': scene_id, 'speaker': speaker, 'line': text})
# ----> 9 df = pd.DataFrame(records)
#
# NameError: name 'pd' is not defined

# %%
speakers = tree.xpath("//tei:sp/tei:speaker", namespaces=ns)
print(f"Found {len(speakers)} speakers.")
for speaker in speakers:
    print("Speaker:", speaker.text)
# Out:
# Found 902 speakers.
# Speaker: FAUST.
# Speaker: GEIST.
# Speaker: FAUST
# Speaker: GEIST.
# Speaker: FAUST.
# Speaker: GEIST.
# Speaker: FAUST.
# Speaker: GEIST.
# Speaker: FAUST.
# Speaker: GEIST.
# Speaker: FAUST
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST
# Speaker: CHOR DER ENGEL.
# Speaker: FAUST.
# Speaker: CHOR DER WEIBER.
# Speaker: CHOR DER ENGEL.
# Speaker: FAUST.
# Speaker: CHOR DER JÜNGER.
# Speaker: CHOR DER ENGEL.
# Speaker: EINIGE HANDWERKSBURSCHEN.
# Speaker: ANDRE.
# Speaker: DIE ERSTEN.
# Speaker: EIN HANDWERKSBURSCH.
# Speaker: ZWEITER.
# Speaker: DIE ZWEITEN.
# Speaker: EIN DRITTER.
# Speaker: VIERTER.
# Speaker: FÜNFTER.
# Speaker: DIENSTMÄDCHEN.
# Speaker: ANDRE.
# Speaker: ERSTE.
# Speaker: ANDRE.
# Speaker: SCHÜLER.
# Speaker: BÜRGERMÄDCHEN.
# Speaker: ZWEITER SCHÜLER
# Speaker: ERSTER.
# Speaker: BÜRGER.
# Speaker: BETTLER
# Speaker: ANDRER BÜRGER.
# Speaker: DRITTER BÜRGER.
# Speaker: ALTE
# Speaker: BÜRGERMÄDCHEN.
# Speaker: DIE ANDRE.
# Speaker: SOLDATEN.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: ALTER BAUER.
# Speaker: FAUST.
# Speaker: ALTER BAUER.
# Speaker: ALLE.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST.
# Speaker: WAGNER.
# Speaker: FAUST
# Speaker: GEISTER
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: GEISTER.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: GEISTERCHOR
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: MEPHISTOPHELES
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER.
# Speaker: MEPHISTOPHELES.
# Speaker: SCHÜLER
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FROSCH.
# Speaker: BRANDER.
# Speaker: FROSCH
# Speaker: BRANDER.
# Speaker: FROSCH.
# Speaker: SIEBEL.
# Speaker: ALTMAYER.
# Speaker: SIEBEL.
# Speaker: FROSCH.
# Speaker: ALTMAYER.
# Speaker: FROSCH.
# Speaker: BRANDER.
# Speaker: FROSCH
# Speaker: SIEBEL.
# Speaker: FROSCH.
# Speaker: SIEBEL.
# Speaker: BRANDER
# Speaker: CHORUS
# Speaker: BRANDER.
# Speaker: CHORUS.
# Speaker: BRANDER.
# Speaker: CHORUS.
# Speaker: SIEBEL.
# Speaker: BRANDER.
# Speaker: ALTMAYER.
# Speaker: MEPHISTOPHELES.
# Speaker: BRANDER.
# Speaker: FROSCH.
# Speaker: SIEBEL.
# Speaker: FROSCH.
# Speaker: BRANDER.
# Speaker: ALTMAYER.
# Speaker: FROSCH.
# Speaker: MEPHISTOPHELES
# Speaker: FAUST.
# Speaker: SIEBEL.
# Speaker: MEPHISTOPHELES.
# Speaker: ALTMAYER.
# Speaker: FROSCH.
# Speaker: MEPHISTOPHELES.
# Speaker: ALTMAYER
# Speaker: SIEBEL.
# Speaker: FROSCH.
# Speaker: MEPHISTOPHELES.
# Speaker: FROSCH.
# Speaker: MEPHISTOPHELES.
# Speaker: ALTMAYER.
# Speaker: MEPHISTOPHELES.
# Speaker: SIEBEL.
# Speaker: MEPHISTOPHELES.
# Speaker: FROSCH.
# Speaker: MEPHISTOPHELES
# Speaker: BRANDER.
# Speaker: MEPHISTOPHELES.
# Speaker: CHORUS
# Speaker: FROSCH.
# Speaker: SIEBEL.
# Speaker: BRANDER.
# Speaker: ALTMAYER.
# Speaker: MEPHISTOPHELES.
# Speaker: SIEBEL.
# Speaker: MEPHISTOPHELES.
# Speaker: SIEBEL.
# Speaker: FROSCH.
# Speaker: ALTMAYER
# Speaker: MEPHISTOPHELES.
# Speaker: BRANDER.
# Speaker: ALTMAYER.
# Speaker: MEPHISTOPHELES
# Speaker: FROSCH.
# Speaker: MEPHISTOPHELES.
# Speaker: ALTMAYER
# Speaker: FROSCH.
# Speaker: MEPHISTOPHELES
# Speaker: ALTMAYER.
# Speaker: MEPHISTOPHELES
# Speaker: BRANDER.
# Speaker: MEPHISTOPHELES
# Speaker: BRANDER.
# Speaker: SIEBEL
# Speaker: MEPHISTOPHELES
# Speaker: ALTMAYER.
# Speaker: MEPHISTOPHELES.
# Speaker: ALTMAYER.
# Speaker: MEPHISTOPHELES
# Speaker: ALLE
# Speaker: MEPHISTOPHELES.
# Speaker: ALLE
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: SIEBEL
# Speaker: MEPHISTOPHELES
# Speaker: SIEBEL.
# Speaker: FROSCH.
# Speaker: ALTM.
# Speaker: SIEBEL.
# Speaker: MEPHISTOPHELES.
# Speaker: SIEBEL.
# Speaker: BRANDER.
# Speaker: ALTMAYER
# Speaker: SIEBEL.
# Speaker: MEPHISTOPHELES
# Speaker: ALTMAYER.
# Speaker: FROSCH.
# Speaker: SIEBEL.
# Speaker: BRANDER.
# Speaker: MEPHISTOPHELES
# Speaker: SIEBEL.
# Speaker: ALTMAYER.
# Speaker: FROSCH.
# Speaker: BRANDER
# Speaker: ALTMAYER.
# Speaker: FROSCH.
# Speaker: SIEBEL.
# Speaker: ALTMAYER.
# Speaker: SIEBEL.
# Speaker: FROSCH.
# Speaker: BRANDER.
# Speaker: ALTMAYER.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: DIE TIERE.
# Speaker: MEPHISTOPHELES.
# Speaker: DIE TIERE.
# Speaker: MEPHISTOPHELES
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: DIE TIERE.
# Speaker: MEPHISTOPHELES.
# Speaker: DER KATER
# Speaker: MEPHISTOPHELES.
# Speaker: DER KATER.
# Speaker: MEPHISTOPHELES.
# Speaker: DER KATER
# Speaker: MEPHISTOPHELES
# Speaker: KATER UND KÄTZIN.
# Speaker: MEPHISTOPHELES.
# Speaker: DER KATER.
# Speaker: FAUST
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST
# Speaker: FAUST
# Speaker: MEPHISTOPHELES
# Speaker: DIE TIERE.
# Speaker: FAUST
# Speaker: DIE HEXE.
# Speaker: MEPHISTOPHELES
# Speaker: DIE HEXE.
# Speaker: MEPHISTOPHELES.
# Speaker: DIE HEXE
# Speaker: MEPHISTOPHELES.
# Speaker: DIE HEXE.
# Speaker: MEPHISTOPHELES.
# Speaker: DIE HEXE
# Speaker: MEPHISTOPHELES
# Speaker: DIE HEXE.
# Speaker: MEPHISTOPHELES.
# Speaker: DIE HEXE.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: DIE HEXE
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: MEPHISTOPHELES.
# Speaker: MEPHISTOPHELES.
# Speaker: DIE HEXE.
# Speaker: MEPHISTOPHELES
# Speaker: DIE HEXE.
# Speaker: MEPHISTOPHELES
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: MARGARETE
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST
# Speaker: MEPHISTOPHELES
# Speaker: FAUST
# Speaker: MEPHISTOPH.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: MARGARETE
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE
# Speaker: MARGARETE.
# Speaker: MARTHE.
# Speaker: MARGARETE.
# Speaker: MARTHE.
# Speaker: MARGARETE.
# Speaker: MARTHE
# Speaker: MARGARETE.
# Speaker: MARTHE.
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES
# Speaker: MARTHE
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES
# Speaker: MARGARETE.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE
# Speaker: FAUST.
# Speaker: MARGARETE
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARTHE
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE.
# Speaker: MEPHISTOPHELES.
# Speaker: MARGARETE.
# Speaker: FAUST
# Speaker: MARGARETE
# Speaker: FAUST
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARTHE.
# Speaker: MARGARETE.
# Speaker: MARGARETE.
# Speaker: FAUST
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: LIESCHEN.
# Speaker: GRETCHEN.
# Speaker: LIESCHEN.
# Speaker: GRETCHEN.
# Speaker: LIESCHEN.
# Speaker: GRETCHEN.
# Speaker: LIESCHEN.
# Speaker: GRETCHEN.
# Speaker: LIESCHEN.
# Speaker: GRETCHEN.
# Speaker: LIESCHEN.
# Speaker: GRETCHEN.
# Speaker: LIESCHEN.
# Speaker: GRETCHEN
# Speaker: GRETCHEN
# Speaker: VALENTIN
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: VALENTIN
# Speaker: MEPHISTOPHELES.
# Speaker: VALENTIN.
# Speaker: MEPHISTOPHELES
# Speaker: VALENTIN.
# Speaker: MEPHISTOPHELES.
# Speaker: VALENTIN.
# Speaker: MEPHISTOPHELES.
# Speaker: VALENTIN.
# Speaker: MEPHISTOPHELES
# Speaker: VALENTIN
# Speaker: MEPHISTOPHELES.
# Speaker: MARTHE
# Speaker: GRETCHEN
# Speaker: MARTHE
# Speaker: VOLK.
# Speaker: MARTHE
# Speaker: GRETCHEN
# Speaker: VOLK.
# Speaker: GRETCHEN.
# Speaker: VALENTIN.
# Speaker: GRETCHEN.
# Speaker: VALENTIN.
# Speaker: MARTHE.
# Speaker: VALENTIN.
# Speaker: GRETCHEN.
# Speaker: VALENTIN.
# Speaker: BÖSER GEIST.
# Speaker: GRETCHEN.
# Speaker: CHOR.
# Speaker: BÖSER GEIST.
# Speaker: GRETCHEN.
# Speaker: CHOR.
# Speaker: GRETCHEN.
# Speaker: BÖSER GEIST.
# Speaker: CHOR.
# Speaker: BÖSER GEIST.
# Speaker: CHOR.
# Speaker: GRETCHEN.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: IRRLICHT.
# Speaker: MEPHISTOPHELES.
# Speaker: IRRLICHT.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: HEXEN IM CHOR.
# Speaker: STIMME.
# Speaker: CHOR.
# Speaker: STIMME.
# Speaker: STIMME.
# Speaker: STIMME.
# Speaker: STIMME.
# Speaker: HEXEN.
# Speaker: HEXENMEISTER.
# Speaker: ANDRE HÄLFTE.
# Speaker: STIMME
# Speaker: STIMMEN
# Speaker: BEIDE CHÖRE.
# Speaker: STIMME
# Speaker: STIMME
# Speaker: STIMME
# Speaker: BEIDE CHÖRE.
# Speaker: HALBHEXE
# Speaker: CHOR DER HEXEN.
# Speaker: BEIDE CHÖRE.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: GENERAL.
# Speaker: MINISTER.
# Speaker: PARVENU.
# Speaker: AUTOR.
# Speaker: MEPHISTOPHELES
# Speaker: TRÖDELHEXE.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST
# Speaker: DIE SCHÖNE.
# Speaker: MEPHISTOPHELES
# Speaker: DIE ALTE.
# Speaker: PROKTOPHANTASMIST.
# Speaker: DIE SCHÖNE
# Speaker: FAUST
# Speaker: PROKTOPHANTASMIST.
# Speaker: DIE SCHÖNE.
# Speaker: PROKTOPHANTASMIST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: SERVIBILIS.
# Speaker: MEPHISTOPHELES.
# Speaker: THEATERMEISTER.
# Speaker: HEROLD.
# Speaker: OBERON.
# Speaker: PUCK.
# Speaker: ARIEL.
# Speaker: OBERON.
# Speaker: TITANIA.
# Speaker: ORCHESTER TUTTI
# Speaker: SOLO.
# Speaker: EIN PÄRCHEN.
# Speaker: NEUGIERIGER REISENDER.
# Speaker: ORTHODOX.
# Speaker: NORDISCHER KÜNSTLER.
# Speaker: PURIST.
# Speaker: JUNGE HEXE.
# Speaker: MATRONE.
# Speaker: KAPELLMEISTER.
# Speaker: WINDFAHNE
# Speaker: WINDFAHNE
# Speaker: XENIEN.
# Speaker: HENNINGS.
# Speaker: MUSAGET.
# Speaker: NEUGIERIGER REISENDER.
# Speaker: KRANICH.
# Speaker: WELTKIND.
# Speaker: TÄNZER.
# Speaker: TANZMEISTER.
# Speaker: FIDELER.
# Speaker: DOGMATIKER.
# Speaker: IDEALIST.
# Speaker: REALIST.
# Speaker: SUPERNATURALIST.
# Speaker: SKEPTIKER.
# Speaker: KAPELLMEISTER.
# Speaker: DIE GEWANDTEN.
# Speaker: DIE UNBEHÜLFLICHEN.
# Speaker: IRRLICHTER.
# Speaker: STERNSCHNUPPE.
# Speaker: DIE MASSIVEN.
# Speaker: PUCK.
# Speaker: ARIEL.
# Speaker: ORCHESTER.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES.
# Speaker: FAUST
# Speaker: FAUST
# Speaker: MARGARETE
# Speaker: FAUST
# Speaker: MARGARETE
# Speaker: FAUST.
# Speaker: MARGARETE
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST
# Speaker: MARGARETE
# Speaker: FAUST
# Speaker: MARGARETE
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MEPHISTOPHELES
# Speaker: MARGARETE.
# Speaker: FAUST.
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES
# Speaker: MARGARETE.
# Speaker: MEPHISTOPHELES.
# Speaker: STIMME
# Speaker: MEPHISTOPHELES
# Speaker: STIMME

# %%
lines = tree.xpath("//tei:l", namespaces=ns)
for line in lines[:10]:
    print("Line:", line.text)
# Out:
# Line: Habe nun, ach! Philosophie,
# Line: Juristerei und Medizin,
# Line: Und leider auch Theologie
# Line: Durchaus studiert, mit heißem Bemühn.
# Line: Da steh' ich nun, ich armer Tor,
# Line: Und bin so klug als wie zuvor!
# Line: Heiße Magister, heiße Doktor gar,
# Line: Und ziehe schon an die zehen Jahr'
# Line: Herauf, herab und quer und krumm
# Line: Meine Schüler an der Nase herum –

# %%
lines_text = [line.text for line in lines if line.text is not None]
print(f"Total lines with text: {len(lines_text)}")
# Out:
# Total lines with text: 4334

# %% [markdown]
# # Rhyme Scheme Detection

# %%
lines_text = [line.text for line in lines]
# Remove None or empty lines
lines_text = [line for line in lines_text if line and line.strip()]

last_words = []
for line in lines_text:
    tokens = line.split()
    # look from the end for the first non-punctuation word
    while True:
    # pop tokens until a non-punctuation word is found
        tok = tokens.pop() 
        word = tok.strip('.,;:!?…–—-"\'()[]')
        if word:
            last_words.append(word)
            break


def get_rhyme_part(word):
    return word[-3:].lower()

rhyme_parts = [get_rhyme_part(word) for word in last_words]
print("Rhyme parts:", rhyme_parts)
# Out:
# Rhyme parts: ['hie', 'zin', 'gie', 'ühn', 'tor', 'vor', 'gar', 'ahr', 'umm', 'rum', 'nen', 'nen', 'fen', 'fen', 'fel', 'fel', 'sen', 'sen', 'ren', 'ren', 'eld', 'elt', 'ben', 'ben', 'und', 'und', 'eiß', 'eiß', 'elt', 'ält', 'men', 'men', 'ein', 'cht', 'cht', 'ier', 'mir', 'öhn', 'ehn', 'ben', 'ben', 'den', 'den', 'och', 'och', 'cht', 'cht', 'auf', 'ckt', 'auf', 'ckt', 'llt', 'pft', 'pft', 'elt', 'erz', 'mmt', 'erz', 'mmt', 'tur', 'ein', 'nur', 'ein', 'and', 'uch', 'and', 'nug', 'auf', 'auf', 'ist', 'ier', 'ärt', 'mir', 'ört', 'ick', 'nen', 'ück', 'nen', 'ieb', 'len', 'len', 'ieb', 'len', 'cht', 'gen', 'gen', 'cht', 'sen', 'tot', 'sen', 't!‹', 'ebt', 'ebt', 'gen', 'hen', 'gen', 'gen', 'gen', 'nur', 'tur', 'ens', 'ngt', 'ngt', 'ein', 'her', 'her', 'ein', 'gen', 'gen', 'gen', 'gen', 'mir', 'cht', 'det', 'len', 'eht', 'rab', 'an', 'ist', 'ich', 'ißt', 'len', 'len', 'ben', 'ben', 'mir', 'cht', 'gen', 'gen', 'nun', 'cht', 'uen', 'ehn', 'ehn', 'uen', 'ruf', 'huf', 'ben', 'ang', 'ang', 'ert', 'ert', 'urm', 'hen', 'hen', 'urm', 'ab', 'her', 'rab', 'eer', 'ben', 'ben', 'eit', 'eid', 'fst', 'dir', 'fst', 'mir', 'dir', 'enn', 'eit', 'pft', 'lus', 'hte', 'hte', 'muß', 'ren', 'iel', 'ren', 'iel', 'ren', 'ren', 'ist', 'mag', 'ist', 'tag', 'ten', 'ten', 'gen', 'ngt', 'gen', 'ngt', 'men', 'aus', 'men', 'aus', 'fen', 'eht', 'fen', 'eht', 'ück', 'ück', 'inn', 'tor', 'inn', 'vor', 'gen', 'gen', 'ind', 'elt', 'ind', 'elt', 'ang', 'ben', 'ben', 'ang', 'ben', 'igt', 'cht', 'ben', 'nen', 'llt', 'llt', 'zen', 'zen', 'cht', 'cht', 'eit', 'eit', 'eln', 'ißt', 'ist', 'eln', 'mer', 'von', 'mer', 'ion', 'men', 'men', 'ist', 'nen', 'ißt', 'nen', 'nnt', 'ten', 'ten', 'nnt', 'cht', 'hen', 'cht', 'hen', 'age', 'age', 'sen', 'sen', 'det', 'ebt', 'äbt', 'det', 'nen', 'dir', 'nen', 'los', 'lte', 'roß', 'lte', 'hon', 'eit', 'eit', 'ohn', 'aft', 'ßen', 'ßen', 'ßen', 'fft', 'sen', 'sen', 'aft', 'cke', 'roß', 'cke', 'los', 'den', 'ang', 'den', 'ang', 'gen', 'an', 'gen', 'ahn', 'hle', 'hle', 'lug', 'ert', 'nug', 'zen', 'zen', 'ruh', 'zu', 'nen', 'ift', 'fft', 'nen', 'hlt', 'hlt', 'ebt', 'äbt', 'and', 'get', 'and', 'get', 'hlt', 'sen', 'ält', 'sen', 'her', 'ret', 'wer', 'ret', 'ein', 'gel', 'ein', 'gel', 'tag', 'ben', 'mag', 'ben', 'cht', 'hte', 'cht', 'hte', 'aßt', 'ast', 'zen', 'ast', 'zen', 'lle', 'net', 'lle', 'eht', 'ole', 'ole', 'nst', 'fte', 'fte', 'nst', 'ert', 'ert', 'ach', 'sen', 'ßen', 'tag', 'gen', 'eit', 'gen', 'eit', 'nne', 'du', 'nne', 'zu', 'ßen', 'cht', 'sen', 'cht', 'ben', 'mmt', 'ben', 'mmt', 'ßen', 'ale', 'ale', 'cht', 'ste', 'ste', 'cht', 'cht', 'ren', 'ren', 'cht', 'hen', 'gen', 'cht', 'hle', 'hle', 'ele', 'cht', 'den', 'hen', 'hen', 'hen', 'den', 'ton', 'nde', 'hon', 'nde', 'ang', 'ang', 'nde', 'ien', 'egt', 'uen', 'den', 'wir', 'den', 'ier', 'den', 'nde', 'nde', 'nde', 'den', 'ind', 'ube', 'ind', 'ube', 'ind', 'ben', 'önt', 'hnt', 'ben', 'kuß', 'lle', 'lle', 'nuß', 'nen', 'ehn', 'nen', 'ehn', 'ele', 'ück', 'hle', 'ück', 'der', 'der', 'ene', 'ben', 'ene', 'ben', 'nah', 'ust', 'da', 'nen', 'ück', 'nen', 'ück', 'den', 'hoß', 'den', 'los', 'den', 'den', 'den', 'den', 'den', 'nah', 'da', 'aus', 'aus', 'ern', 'ehn', 'hön', 'du', 'ern', 'ihr', 'ier', 'rte', 'ell', 'ell', 'rte', 'ück', 'hen', 'ück', 'hen', 'lan', 'an', 'ein', 'ein', 'ten', 'ten', 'ack', 'ack', 'ben', 'ach', 'ben', 'ach', 'wei', 'gen', 'bei', 'gen', 'itt', 'mit', 'ert', 'ren', 'hrt', 'ren', 'ter', 'ter', 'er', 'mer', 'mer', 'her', 'uen', 'rot', 'uen', 'not', 'ern', 'ern', 'tag', 'gen', 'rei', 'kei', 'gen', 'aus', 'ten', 'aus', 'ten', 'ehn', 'ten', 'ehn', 'ten', 'lut', 'fen', 'gut', 'fen', 'cht', 'hen', 'cht', 'hen', 'all', 'nen', 'all', 'nen', 'hen', 'nen', 'zen', 'nen', 'nen', 'hen', 'ohn', 'ben', 'ude', 'ben', 'men', 'ben', 'gen', 'ben', 'hen', 'ohn', 'ten', 'von', 'che', 'ick', 'ück', 'che', 'ück', 'nur', 'ses', 'lur', 'ßes', 'ben', 'ben', 'ier', 'für', 'hen', 'hen', 'tor', 'vor', 'ern', 'rrn', 'den', 'ern', 'den', 'ern', 'nge', 'cht', 'nge', 'ägt', 'nge', 'egt', 'den', 'ahn', 'den',  ...

# %%
# %pip install lxml pandas networkx matplotlib regex
# Out:
# Requirement already satisfied: lxml in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (5.4.0)
# Requirement already satisfied: pandas in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (2.3.0)
# Requirement already satisfied: networkx in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (3.5)
# Requirement already satisfied: matplotlib in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (3.10.3)
# Requirement already satisfied: regex in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (2024.11.6)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\amnes\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\amnes\appdata\roaming\python\python311\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\amnes\anaconda3\envs\faust-tei\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\amnes\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
freq = df['speaker'].value_counts().reset_index()
freq.columns = ['speaker', 'count']

plt.figure(figsize=(8,6))
plt.bar(freq['speaker'], freq['count'])
plt.xticks(rotation=45, ha='right')
plt.title('Lines per Speaker')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 freq = df['speaker'].value_counts().reset_index()
#       2 freq.columns = ['speaker', 'count']
#       4 plt.figure(figsize=(8,6))
#
# NameError: name 'df' is not defined
